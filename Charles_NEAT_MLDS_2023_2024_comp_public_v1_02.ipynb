# %% [markdown]
# ### Imports

# %%
from matplotlib import rc
from matplotlib import colors
from matplotlib.patches import FancyArrowPatch
rc('animation', html='jshtml')

from math import *
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
import matplotlib.animation as animation
import abc
from numpy.typing import NDArray

from scipy import stats

# %% [markdown]
# ### Game Plotter.
# Plots are generated with game history and actions of agents. You should not need to edit this code.

# %%
#generate a fake game with walls and agents
walls = np.random.binomial(1, 0.2, (8,8))
test_map = [np.random.randint(0,4, (8,8)) for i in range(10)]
for i in test_map:
  i[i==1] = 0
  i[walls== 1] = 1
# [empty, wall, friendly, enemy]

#generate actions taken by agents
action_hist = [(np.random.randint(0, 25, (8,8)),np.random.randint(11, 13, (8,8))) for _ in range(10)]

# RGB color definitions
color_empty = (0.98, 0.98, 0.98)  # Slightly off-white for empty cells
color_wall = (0.3, 0.3, 0.3)  # Dark grey for walls
color_p1 = (0.8, 0.2, 0.2)  # Less saturated red for player 1
color_p2 = (0.2, 0.2, 0.8)  # Less saturated blue for player 2
color_p1_attack = (1.0, 0.5, 0.5)  # Light red for player 1 attack
color_p2_attack = (0.5, 0.5, 1.0)  # Light blue for player 2 attack


import matplotlib.pyplot as plt
from matplotlib.patches import Arc, RegularPolygon
import numpy as np
from numpy import radians as rad

#draw the circle
def drawCirc(ax,radius,centX,centY,angle_,theta2_, line_width = 3,color_='black'):
    #========Line
    arc = Arc([centX,centY],radius,radius,angle=angle_,
          theta1=0,theta2=theta2_,capstyle='round',linestyle='-',lw=line_width,color=color_)
    ax.add_patch(arc)


# draw the attack lines from agents
def calculate_attack_lines(frame_matrix, action_matrix, player_number):
    lines = []
    for i in range(frame_matrix.shape[0]):
        for j in range(frame_matrix.shape[1]):
            if frame_matrix[i, j] == player_number:
                action = int(action_matrix[i, j])
                direction = np.unravel_index(action, (5, 5))
                direction = (direction[0] - 2, direction[1] - 2)  # Adjust to get -2 to 2 range
                start = (j, i)  # Center of the cell

                if direction == (0, 0):  # Self-attack
                    lines.append((start, 'self'))
                else:
                    end = (start[0] + direction[1], start[1] + direction[0])  # Calculate end point
                    lines.append((start, end))

    return lines

#frame function - used to draw all elements in each frame
def frame(w, im, p1_lines, p2_lines, ax, cmap, norm):
    height, width = w.shape
    im.set_data(w)
    ax.clear()
    ax.imshow(w, cmap=cmap, norm=norm, origin = 'upper')


    # Draw attack lines for both players
    for line in p1_lines:
        if line[1] == 'self':  # Self-attack
            drawCirc(ax,0.35,line[0][0],line[0][1],90,270,line_width = 3,color_=color_p1_attack)
        else:
            ax.annotate('', xy=line[1], xytext=line[0],
                        arrowprops=dict(arrowstyle="->, head_length=.9, head_width=0.3", color=color_p1_attack, linewidth=3), annotation_clip = False)
    # Repeat for player 2
    for line in p2_lines:
        if line[1] == 'self':  # Self-attack
            drawCirc(ax,0.35,line[0][0],line[0][1],90,270,line_width = 3,color_=color_p2_attack)
        else:
            ax.annotate('', xy=line[1], xytext=line[0],
                        arrowprops=dict(arrowstyle="->, head_length=.9, head_width=0.3", color=color_p2_attack, linewidth=3), annotation_clip = False)

    # Rest of the function...

    # Add grid lines for visual separation of cells
    ax.set_xticks(np.arange(-0.5, width, 1), minor=True)
    ax.set_yticks(np.arange(-0.5, height, 1), minor=True)
    ax.grid(which="minor", color="grey", linestyle='-', linewidth=0.5)
    ax.tick_params(which="minor", size=0)

    return im

def anim_builder(frames, action_hist, fig_size = (4,4)):
    """
    Builds the animation with attack lines if provided.
    """
    fig, ax = plt.subplots(figsize=(6,6))
    cmap = colors.ListedColormap([color_empty, color_wall, color_p1, color_p2])
    bounds = [-0.5, 0.5, 1.5, 2.5, 3.5]
    norm = colors.BoundaryNorm(bounds, cmap.N)
    im = ax.imshow(frames[0], cmap=cmap, norm=norm)
    #h,w = frames[0].shape

    def frame_with_lines(frame_num):
        if frame_num+1 < len(action_hist):
          p1_lines = calculate_attack_lines(frames[frame_num], action_hist[frame_num+1][0], 2) if action_hist else []
          p2_lines = calculate_attack_lines(frames[frame_num], action_hist[frame_num+1][1], 3) if action_hist else []
        else:
          p1_lines = []
          p2_lines = []
        return frame(frames[frame_num], im, p1_lines, p2_lines, ax, cmap, norm)

    anim = animation.FuncAnimation(fig, frame_with_lines, frames=len(frames), blit=False, repeat=True)
    plt.close(fig)
    return anim

# Create the animation with attack lines
anim = anim_builder(test_map, action_hist)
#display the result in the notebook
anim
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img097d7a228ed04cd29253c292bff01bbc">
#   <div class="anim-controls">
#     <input id="_anim_slider097d7a228ed04cd29253c292bff01bbc" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim097d7a228ed04cd29253c292bff01bbc.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim097d7a228ed04cd29253c292bff01bbc.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim097d7a228ed04cd29253c292bff01bbc.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim097d7a228ed04cd29253c292bff01bbc.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim097d7a228ed04cd29253c292bff01bbc.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim097d7a228ed04cd29253c292bff01bbc.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim097d7a228ed04cd29253c292bff01bbc.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim097d7a228ed04cd29253c292bff01bbc.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim097d7a228ed04cd29253c292bff01bbc.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim097d7a228ed04cd29253c292bff01bbc.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select097d7a228ed04cd29253c292bff01bbc"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_097d7a228ed04cd29253c292bff01bbc"
#              >
#       <label for="_anim_radio1_097d7a228ed04cd29253c292bff01bbc">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_097d7a228ed04cd29253c292bff01bbc"
#              checked>
#       <label for="_anim_radio2_097d7a228ed04cd29253c292bff01bbc">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_097d7a228ed04cd29253c292bff01bbc"
#              >
#       <label for="_anim_radio3_097d7a228ed04cd29253c292bff01bbc">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img097d7a228ed04cd29253c292bff01bbc";
#     var slider_id = "_anim_slider097d7a228ed04cd29253c292bff01bbc";
#     var loop_select_id = "_anim_loop_select097d7a228ed04cd29253c292bff01bbc";
#     var frames = new Array(10);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjguMCwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy81sbWrAAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAABlXUlEQ

# %%
anim.save('test_anim.gif', writer='pillow', fps=5)

# %%
#call for getting adjacent cell features
# given x,y, return cells in range
def get_cell_feats(state_mat, y, x, n=1):
    rows, cols = state_mat.shape

    if not 0 <= x < cols:
        raise ValueError('Invalid X coordinate')
    if not 0 <= y < rows:
        raise ValueError('Invalid Y coordinate')

    y_indices = [(y+i) % rows for i in range(-n, n+1)]
    x_indices = [(x+i) % cols for i in range(-n, n+1)]

    return state_mat[np.ix_(y_indices, x_indices)]

# %% [markdown]
# ## Agent Class + Example Agents. Feel Free to modify or train off of!

# %% [markdown]
# ### The Agent Superclass.
# Your code will need to extend this class.

# %%
class Agent():
  __metaclass__ = abc.ABCMeta

  def __init__(self,
                 obs_onehot: bool = False,
                 attack_map: bool = False,
                 attack_map_logits: bool = False,
                 ):
        """
        :param obs_onehot: Determines whether the observation that is received is one-hot encoded or not
        :type obs_onehot: bool
        :param attack_map: Determines whether you pass in a probability map for each cell's attack
        (4 dimensional array for your total action)
        :type attack_map: bool
        :param attack_map_logits: If you pass in a map for each cell's attack, this determines whether it
        is a logit or probability map
        :type attack_map_logits: bool
        """
        self.obs_onehot = obs_onehot
        self.attack_map = attack_map
        self.attack_map_logits = attack_map_logits

  @abc.abstractmethod
  def policy(self, obs: NDArray) -> NDArray:
      raise NotImplementedError("Please implement the policy method!")

  # stores game data (left to you for training)
  def cache(self, args):
    pass

# %% [markdown]
# ### NEAT Agent
#
# Uses NEAT to find the best possible strategy

# %%
class neat_agent(Agent):
  desired_length = 2500

  def cache(self, step):
    state = step[0]
    next_state = step[1]
    action = step[2]
    reward = step[3]


  def __init__(self,
                 obs_onehot: bool = False,
                 attack_map: bool = False,
                 attack_map_logits: bool = False,
                 ):
        self.obs_onehot = obs_onehot
        self.attack_map = attack_map
        self.attack_map_logits = attack_map_logits
        self.adj_mat_ind = None
        return

  def policy(self, state_mat, net, action_space= None, obs_space = None):
    attack_mat = np.zeros(state_mat.shape).astype(int)

    # Set the desired length (2500 in this case)
    desired_length = 2500

    # Flatten the state_mat
    flattened_state = state_mat.flatten()

    # Calculate the number of zeros to add
    zeros_to_add = max(0, desired_length - flattened_state.size)

    # Pad the flattened array with zeros
    padded_state = np.pad(flattened_state, (0, zeros_to_add), mode='constant')

    padded = np.append(padded_state, [state_mat.shape[0], state_mat.shape[1], 0, 0])

    rows, cols = state_mat.shape
    for i in range(rows):
      for j in range(cols):
        if (state_mat[i, j] == 2):
          padded[2500] = i;
          padded[2501] = j;
          output = net.activate((padded))
          bit0 = 1 if output[0] > 0.5 else 0
          bit1 = 1 if output[1] > 0.5 else 0
          bit2 = 1 if output[2] > 0.5 else 0
          bit3 = 1 if output[3] > 0.5 else 0
          bit4 = 1 if output[4] > 0.5 else 0
          ret = bit0*16 + bit1*8 + bit2*4 + bit3*2 + bit4
          if (ret > 24):
            ret = 12
          attack_mat[i, j] = ret

    return attack_mat.astype(int)

# %% [markdown]
# ### Random Agent
#
# Chooses a random point to attack

# %%
class rand_agent(Agent):

  def policy(self, state_mat, net, action_space = None, obs_space = None):
    h = state_mat.shape[0]
    w = state_mat.shape[1]
    attack_mat =np.random.uniform(0,25,(h,w)).astype(int)

    return attack_mat.astype(int)

# %% [markdown]
# ### First Enemy Agent
#
# Attacks the first enemy it sees (So starting with top left going down)

# %%
class first_enemy_agent(Agent):
  def simple_adj(self, feat_mat):
    feat_mat = feat_mat.reshape(-1,1)

    enemy_list = np.argwhere(feat_mat >= 3)[:,0]
    empty_list = np.argwhere(feat_mat == 0)[:,0]

    if len(enemy_list)>=1: #if there is at least one enemy
      return enemy_list[0]
    elif len(empty_list)>=1: #if there is at least one empty
      return empty_list[0]
    else:
      return 12

  #get the adjacent features for a given x,y cell
  def get_cell_feats(self,state_mat, x,y, n = 2):
    h,w = state_mat.shape
    adj_width = 2*n+1

    xind,yind = np.indices((adj_width,adj_width))
    xind = (xind -n +x)%h
    yind = (yind -n +y)%w

    #gets a matrix of the adjacent cells by 1
    adj_vals = state_mat[xind,yind]
    return adj_vals

  def policy(self, state_mat, action_space = None, obs_space = None):
    attack_mat =np.zeros(state_mat.shape)

    for i in range(attack_mat.shape[0]):
      for j in range(attack_mat.shape[1]):
        attack_mat[i,j] = self.simple_adj(self.get_cell_feats(state_mat, i,j,2)) #get cell feats returns adjacent cells

    return attack_mat.astype(int)

# %% [markdown]
# ### Random Enemy Agent
#
# Chooses a random enemy within reach and attacks it

# %%
class rand_enemy_agent(Agent):

  #function for individual cell logic
  def rand_adj(self, feat_mat):

    feat_mat = feat_mat.reshape(-1,1)

    enemy_list = np.argwhere(feat_mat >=3)[:,0] #enemies are 3 or higher
    empty_list = np.argwhere(feat_mat == 0)[:,0] #empties are always 0

    if len(enemy_list)>=1:
      return np.random.choice(enemy_list,1)[0]
    if len(empty_list)>=1:
      return np.random.choice(empty_list,1)[0]
    else:
      return 12

  #Gets the values of the cells adjacent to a given x, y
  def get_cell_feats(self,state_mat, x,y, n = 2):
    h,w = state_mat.shape
    adj_width = 2*n+1

    xind,yind = np.indices((adj_width,adj_width))
    xind = (xind -n +x)%h
    yind = (yind -n +y)%w

    #gets a matrix of the adjacent cells by 1
    adj_vals = state_mat[xind,yind]
    return adj_vals

  #the global policy for this agent
  def policy(self, state_mat, net, action_space = None, obs_space = None):
    attack_mat =np.zeros(state_mat.shape)
    for i in range(attack_mat.shape[0]):
      for j in range(attack_mat.shape[1]):
        attack_mat[i,j] = self.rand_adj(self.get_cell_feats(state_mat, i,j, 2)) #get cell feats returns adjacent cells

    return attack_mat.astype(int)

# %% [markdown]
# ### Defensive Random Enemy Agent

# %%
class def_rand_agent(Agent):

  #function for individual cell logic
  def rand_adj(self, feat_mat):

    feat_mat = feat_mat.reshape(-1,1)

    enemy_list = np.argwhere(feat_mat >=3)[:,0] #enemies are 3 or higher
    empty_list = np.argwhere(feat_mat == 0)[:,0] #empties are always 0
    friendly_list = np.argwhere(feat_mat == 2)[:,0] #friendlies are always 0

    if len(enemy_list)>=1:
      return np.random.choice(enemy_list,1)[0]
    if len(empty_list)>=1:
      if len(friendly_list) >=12:
        return np.random.choice(friendly_list,1)[0]
      return np.random.choice(empty_list,1)[0]
    else:
      return 12

  #Gets the values of the cells adjacent to a given x, y
  def get_cell_feats(self,state_mat, x,y, n = 2):
    h,w = state_mat.shape
    adj_width = 2*n+1

    xind,yind = np.indices((adj_width,adj_width))
    xind = (xind -n +x)%h
    yind = (yind -n +y)%w

    #gets a matrix of the adjacent cells by 1
    adj_vals = state_mat[xind,yind]
    return adj_vals

  #the global policy for this agent
  def policy(self, state_mat, action_space = None, obs_space = None):
    attack_mat =np.zeros(state_mat.shape)
    for i in range(attack_mat.shape[0]):
      for j in range(attack_mat.shape[1]):
        attack_mat[i,j] = self.rand_adj(self.get_cell_feats(state_mat, i,j, 2)) #get cell feats returns adjacent cells

    return attack_mat.astype(int)

# %% [markdown]
# ### Priority Agent
#
# This agent prioritizes low population areas when expanding.

# %%
from scipy import signal

class priority_agent(Agent):

  def __init__(self,
                 obs_onehot: bool = False,
                 attack_map: bool = False,
                 attack_map_logits: bool = False,
                 ):
        self.obs_onehot = obs_onehot
        self.attack_map = attack_map
        self.attack_map_logits = attack_map_logits
        self.adj_mat_ind = None
        return

  #gets the adjacent x,y coordinates to every friendly agent on the board
  def get_adj_indices(self, h, w , n = 1):
    adj_width = 2*n+1
    X,Y = np.indices((h,w))
    x,y = np.indices((adj_width, adj_width))
    x-=n
    y-=n
    X = X.reshape(h,w,1,1) + x
    Y = Y.reshape(h,w,1,1) + y

    X = X%h
    Y = Y%w

    X = X.reshape(h,w,-1)
    Y = Y.reshape(h,w,-1)
    return X, Y

  #gets the population mat from the state_mat
  def get_pop(self, state_mat):
    abs_map = (state_mat>=2) #get locations where there is an agent
    sum_mat = signal.convolve2d(abs_map, np.ones((3,3)), boundary = 'wrap', mode = 'same')
    return sum_mat

  #maximum population among all adjacent spaces to all friendly agents
  def get_max_pop(self, pop_mat):
    adj_pop = pop_mat[self.X_ind, self.Y_ind]
    max_pop = np.max(adj_pop, axis = 2)

    return max_pop


  def smart_adj(self, feat_mat, pop_mat): #helper function from individual cell perspective

    feat_mat = feat_mat.reshape(-1,1)

    enemy_list = np.argwhere(feat_mat >=3)[:,0]
    empty_list = np.argwhere((feat_mat == 0) * (pop_mat<=6))[:,0]

    if len(enemy_list)>=1: #if theres an enemy choose a random enemy
      if np.random.uniform()<0.8:
        return np.random.choice(enemy_list,1)[0]
      return 12

    elif len(empty_list)>=1: # if theres an empty list, choose the option with the lowest population
      enemy_ind = np.argmin(pop_mat[empty_list])
      return empty_list[enemy_ind]
    else:
      return 12

  def policy(self, state_mat, action_space= None, obs_space = None):
    attack_mat =np.zeros(state_mat.shape).astype(int)

    #get the indices for adjacent cells
    if self.adj_mat_ind is None:
      h,w = state_mat.shape
      self.X_ind, self.Y_ind = self.get_adj_indices(h,w,n = 2)


    X_ind = self.X_ind
    Y_ind = self.Y_ind

    pop_mat = self.get_pop(state_mat) #get the one distance population map
    max_pop = self.get_max_pop(pop_mat)

    for i in range(attack_mat.shape[0]): #for each row
      for j in range(attack_mat.shape[1]): #for each column

        current = state_mat[i,j]
        if current == 2:#only run if theres an ally cell here.

          adj_x = X_ind[i,j,:]
          adj_y = Y_ind[i,j,:]

          adj_pop = max_pop[adj_x, adj_y]
          feat_mat = state_mat[adj_x, adj_y]

          ind = self.smart_adj(feat_mat, adj_pop) #get cell feats returns adjacent cells
          attack_mat[i,j] = ind

          a_x = adj_x[ind] #x pos being attacked
          a_y = adj_y[ind] #y pos being attacked

          target = state_mat[a_x, a_y]

          if target == 0: #go back and edit the population map.
            state_mat[a_x, a_y] = 2

            adj_x = X_ind[a_x,a_y,:]
            adj_y = Y_ind[a_x,a_y,:]

            pop_mat[adj_x, adj_y]+=1
            max_pop = self.get_max_pop(pop_mat)

    return attack_mat.astype(int)

# %% [markdown]
# ## Environment Code.

# %%
from scipy import signal


class cgol:
  def  __init__(self, agent_1, agent_2, board_h = 10, board_w = 10, attack_width = 5, max_rounds = 100,map = None):

    self.board_h = board_h
    self.board_w = board_w
    self.view_width = attack_width
    self.view_height = attack_width
    self.max_rounds = max_rounds


    if map is None:
      self.map = np.zeros((self.board_h,self.board_w))
    else:
      self.map = map

    self.agent_1 = agent_1
    self.agent_2 = agent_2

    self.over_pop = 6

    #mapping for action int to
    x_view, y_view = np.indices((5,5))
    x_view-=2
    y_view-=2
    self.x_view = x_view.flatten()
    self.y_view = y_view.flatten()

    self.reset()

  def reset(self):
    self.state_mat = np.zeros((self.board_h,self.board_w)) + self.map

    start_num = 1
    #set starting locations for agent
    game_y = np.random.randint(0,self.board_h, start_num) #starting locations for agent_1_x
    game_x = np.random.randint(0,self.board_w, start_num) #starting locations for agent_1_y
    self.state_mat[game_y, game_x] = 2

    game_y = np.random.randint(0,self.board_h, start_num) #starting locations for agent_1_x
    game_x = np.random.randint(0,self.board_w, start_num) #starting locations for agent_1_y
    self.state_mat[game_y, game_x] = 3

    #recording history
    self.state_history = []
    self.action_history = []
    self.reward_history = []
    self.count = 0

  def get_state(self):
    return self.state_mat

  #moves from cords to attack to attack_map
  #action_map - map of board with actions assigned integer based on coord
  #ex:
  # [1 3 4 5 0 9]      [sum of adjent attacks]
  # [3 4 9 8 6 2]      [                     ]
  # [1 0 6 7 5 3] ---> [                     ]
  # [0 0 0 4 5 6]      [                     ]
  def convert_action_map(self, action_matrix, mask_matrix):

    rows, cols = action_matrix.shape

    # Convert action_matrix to direction coordinates
    directions = np.array(np.unravel_index(action_matrix.ravel(), (5, 5))).T - 2
    y_coords, x_coords = np.indices(action_matrix.shape)

    # Filter directions by mask
    masked_directions = directions[mask_matrix.ravel()]
    y_attacked = (y_coords.ravel()[mask_matrix.ravel()] + masked_directions[:, 0]) % rows
    x_attacked = (x_coords.ravel()[mask_matrix.ravel()] + masked_directions[:, 1]) % cols

    # Aggregate attacks on each cell
    result = np.zeros_like(action_matrix)
    np.add.at(result, (y_attacked, x_attacked), 1)

    return result

  #action_mat_1 - the action being played for this step by agent_1
  #action_mat_2 - the action being played for this step by agent_2
  #returns - reward, done

  # reward based off relative size
  def get_reward(self):
    p1_reward = np.count_nonzero(self.state_mat == 2)
    p2_reward = np.count_nonzero(self.state_mat == 3)
    if (p1_reward > p2_reward):
      p1_reward -= p2_reward
      p2_reward = p1_reward * -1
    else:
      p2_reward -= p1_reward
      p1_reward = p2_reward * -1

    return (p1_reward, p2_reward)

  #allys are always 2, so modify it here.
  def modify_view(self, state_mat, agent_num = 2):
    view = np.copy(state_mat)

    view[state_mat==agent_num] = 2
    view[state_mat==2] = agent_num
    return view

  def get_agent_views(self, state_mat=None):
    state_mat = state_mat if state_mat is not None else self.state_mat
    p1_view = self.modify_view(state_mat, 2)
    p2_view = self.modify_view(state_mat, 3)
    return p1_view, p2_view

  def calculate_winner(self):
    # Flattening the 2D array and then filtering out 0 and 1
    filtered_array = self.state_mat.flatten()
    filtered_array = filtered_array[(filtered_array != 0) & (filtered_array != 1)]

    # Finding the most common value in the filtered array
    mode = stats.mode(filtered_array)
    return mode

  def step(self, actions=(None, None), is_training=True):

    #print(actions)

    p1_action, p2_action = actions
    p1_view, p2_view = self.get_agent_views()
    ##retrieve adjent coordinates
    p1_mask = p1_view==2 #where p1 sees allys
    p2_mask = p2_view==2 #where p2 sees allys

    #translate adjent actions into sum attack matrices
    p1_sum = self.convert_action_map(p1_action, p1_mask)
    p2_sum = self.convert_action_map(p2_action, p2_mask)

    #add an always occuring self attack
    p1_sum += 1*(self.state_mat==2)
    p2_sum += 1*(self.state_mat==3)


    # Calculate total attacks for each cell.
    total_attacks = p1_sum + p2_sum

    rewardReturn = (0,0)

    with np.errstate(divide='ignore', invalid='ignore'):
        p1_win_mask = (total_attacks > 0)&(p1_sum == total_attacks)
        p2_win_mask = (total_attacks > 0)&(p2_sum == total_attacks)

        #print(p1_win_mask)

        both_nonzero_mask = (p1_sum > 0) & (p2_sum > 0)

        random_numbers = np.random.rand(*p1_sum.shape)
        p1_prob = p1_sum / (p1_sum + p2_sum)
        p1_prob[np.isnan(p1_prob)] = 0

        p1_prob_win = random_numbers < p1_prob
        p2_prob_win = random_numbers >= p1_prob
        p1_prob_win = p1_prob_win*both_nonzero_mask
        p2_prob_win = p2_prob_win*both_nonzero_mask

        original_state_mat = np.copy(self.state_mat)
        self.state_mat[p1_win_mask] = 2
        self.state_mat[p1_prob_win] = 2
        a1kills = np.count_nonzero(original_state_mat != self.state_mat)

        original_state_mat = np.copy(self.state_mat)
        self.state_mat[p2_win_mask] = 3
        self.state_mat[p2_prob_win] = 3
        a2kills = np.count_nonzero(original_state_mat != self.state_mat)
        if (a1kills > a2kills):
          a1kills -= a2kills
          a2kills = a1kills * -1
        else:
          a2kills -= a1kills
          a1kills = a2kills * -1
        a1kills *= 100
        a2kills *= 100

        # Convert the tuple to a list to make modifications
        modified_list = list(rewardReturn)

        # Change values in the list
        modified_list[0] = a1kills
        modified_list[1] = a2kills

        # Convert the list back to a tuple
        rewardReturn = tuple(modified_list)

    self.state_mat[self.map==1]=1

    ###ADD PUNISHMENT FOR OVERPOPULATION #################################
    original_state_mat = np.copy(self.state_mat)

    abs_map = (self.state_mat>=2) #get locations where there is an agent
    sum_mat = signal.convolve2d(abs_map, np.ones((3,3)), boundary = 'wrap', mode = 'same')
    excess_mat = sum_mat>self.over_pop
    self.state_mat = self.state_mat * (1-(1*excess_mat))

    # Count the changes where the original value was 2 or 3
    a1deaths = np.count_nonzero((original_state_mat == 2) & (self.state_mat != original_state_mat))
    a2deaths = np.count_nonzero((original_state_mat == 3) & (self.state_mat != original_state_mat))
    a1deaths *= -100
    a2deaths *= -100

    # Convert the tuple to a list to make modifications
    modified_list = list(rewardReturn)

    # Change values in the list
    modified_list[0] -= a1deaths
    modified_list[1] -= a2deaths

    # Convert the list back to a tuple
    rewardReturn = tuple(modified_list)

    self.state_mat[self.map==1]=1 #walls always equal 1

    #####reward! modify as needed (your objective is to win)##############
    reward = self.get_reward()
    reward_list = list(reward)

    # Change values in the list
    reward_list[0] += rewardReturn[0]
    reward_list[1] += rewardReturn[1]

    # Convert the list back to a tuple
    reward = tuple(reward_list)

    #check if game end state is complete
    done = False
      #reward = 10000
    if np.max(self.state_mat) == 1:
      done = True
      #reward = -100
    if self.count >= self.max_rounds:
      done = True

    if not np.any(self.state_mat == 2):
      done = True
    if not np.any(self.state_mat == 3):
      done = True

    self.count+=1

    p1_view, p2_view = self.get_agent_views()
    return (p1_view, p2_view), reward, done

  #returns a history of the game
  def run_game(self, episodes = 10, training=True):
    episode_winner_record = []
    episodes_game_history = []
    episodes_action_history = []

    # set agent flags for training
    self.agent_1.is_training = training
    self.agent_2.is_training = training

    for episode in range(episodes):
      self.reset()
      while True:

          p1_view, p2_view = self.get_agent_views()

          # get attack actions from agent
          p1_action = self.agent_1.policy(p1_view)
          p2_action = self.agent_2.policy(p2_view)

          # Recieve state and reward from environment from chosen actions
          player_views_new, reward, done = self.step((p1_action, p2_action))
          p1_view_new, p2_view_new = player_views_new
          p1_reward, p2_reward = reward

          #print(self.action_history)
          # if training, record data
          if training:
            # example caching of data. Up to you to edit, modify, use, ect
            self.agent_1.cache((p1_view, p1_view_new, p1_action, p1_reward))
            self.agent_2.cache((p2_view, p2_view_new, p2_action, p2_reward))

          # End this episode when `done` is True
          if done:
            episode_winner_record.append(self.calculate_winner())
            episodes_game_history.append(self.state_history)
            episodes_action_history.append(self.action_history)
            break
    return episode_winner_record, episodes_game_history, episodes_action_history

    #evaluate genome
  def eval_genome(self, net1, net2, training=True):
    # set agent flags for training
    self.agent_1.is_training = training
    self.agent_2.is_training = training

    fitness_1 = 0;
    fitness_2 = 0;

    self.reset()
    while True:
        p1_view, p2_view = self.get_agent_views()

        # get attack actions from agent
        p1_action = self.agent_1.policy(p1_view, net1)
        p2_action = self.agent_2.policy(p2_view, net2)

        # Recieve state and reward from environment from chosen actions
        player_views_new, reward, done = self.step((p1_action, p2_action))
        # p1_view_new, p2_view_new = player_views_new
        p1_reward, p2_reward = reward

        # reward based off relative kills divided by 10 to reduce impact
        fitness_1 += (p1_reward/10)
        fitness_2 += (p2_reward/10)

        #print(self.action_history)
        # if training, record data
        # if training:
        #   # example caching of data. Up to you to edit, modify, use, ect
        #   self.agent_1.cache((p1_view, p1_view_new, p1_action, p1_reward))
        #   self.agent_2.cache((p2_view, p2_view_new, p2_action, p2_reward))

        # End this episode when `done` is True
        if done:
          winner = self.calculate_winner()
          if (winner == 2):
            fitness_1 += 10000
            fitness_2 -= 10000
          if (winner == 3):
            fitness_1 -= 10000
            fitness_2 += 10000
          break

    return fitness_1, fitness_2

# %% [markdown]
# ## Test of the game

# %%
pip install neat-python
# Out:
# Requirement already satisfied: neat-python in c:\users\charles\anaconda3\envs\torch\lib\site-packages (0.92)
# Note: you may need to restart the kernel to use updated packages.

# %%
import neat
import os
import random
import pickle

# %%
def run(config_path):
  config = neat.config.Config(neat.DefaultGenome,
                              neat.DefaultReproduction,
                              neat.DefaultSpeciesSet,
                              neat.DefaultStagnation,
                              config_path)
  p = neat.Population(config) # set a population

  p.add_reporter(neat.StdOutReporter(True))
  stats = neat.StatisticsReporter()
  p.add_reporter(stats)

  winner = p.run(run_games,100) # set a fitness function to run X generations

  print('\nBest genome:\n{!s}'.format(winner))

# %%
GEN = 0
def run_games(genomes, config):
    global GEN
    GEN += 1

    agents = []
    ge = []
    nets = []

    for _, g in genomes:
      net = neat.nn.FeedForwardNetwork.create(g, config)
      nets.append(net)
      agents.append(neat_agent())
      g.fitness = 0
      ge.append(g)

    h = random.randint(1, 50)
    w = random.randint(1, 50)

    num_agents = len(agents)
    for i in range(num_agents):
      for j in range(i + 1, i + 4): # next 5 agents compare
        if (j >= num_agents):
           j -= num_agents
        agent_1 = agents[i]
        agent_2 = agents[j]
        test_game = cgol(agent_1, agent_2,board_h = h,board_w = w, max_rounds = 50, map = np.random.binomial(1,0.1,(h,w)))
        fitness_1, fitness_2 = test_game.eval_genome(nets[i], nets[j])
        ge[i].fitness = ge[i].fitness + fitness_1
        ge[j].fitness = ge[j].fitness + fitness_2
    
    for i in range(num_agents):
      for j in range(i + 1, i + 4): # next 5 agents compare
        if (j >= num_agents):
           j -= num_agents
        agent_1 = agents[i]
        agent_2 = rand_agent()
        test_game = cgol(agent_1, agent_2,board_h = h,board_w = w, max_rounds = 50, map = np.random.binomial(1,0.1,(h,w)))
        fitness_1, fitness_2 = test_game.eval_genome(nets[i], nets[j])
        ge[i].fitness = ge[i].fitness + fitness_1
    
    for i in range(num_agents):
      for j in range(i + 1, i + 4): # next 5 agents compare
        if (j >= num_agents):
           j -= num_agents
        agent_1 = agents[i]
        agent_2 = rand_enemy_agent()
        test_game = cgol(agent_1, agent_2,board_h = h,board_w = w, max_rounds = 50, map = np.random.binomial(1,0.1,(h,w)))
        fitness_1, fitness_2 = test_game.eval_genome(nets[i], nets[j])
        ge[i].fitness = ge[i].fitness + fitness_1

    idx = 0
    max = 0
    # Find the index of the maximum value
    for i in range(len(genomes)):
        g = genomes[i][1]
        if (g.fitness > max):
            max = g.fitness
            idx = i - 1
    
    
    print(idx)
    print(max)
    print(len(nets))
    print(len(genomes))
    
    file_path_string = "gen{}.pickle".format(GEN)
    pickle.dump(nets[idx],open(file_path_string, "wb"))
    if max > 50000 or GEN >= 50:
        pickle.dump(nets[idx],open("best.pickle", "wb"))

# %%
if __name__ == "__main__":
  path = "C:\\Users\\Charles\\OneDrive\\Documents\\College\\Engineering_Competitions\\2024-3_MLDS_Long_Comp\\config_feedforward.txt"
  file_path = os.path.normpath(path)
  print(file_path)
  run(file_path)
# Out:
# C:\Users\Charles\OneDrive\Documents\College\Engineering_Competitions\2024-3_MLDS_Long_Comp\config_feedforward.txt
#
#  ****** Running generation 0 ******
#
# 0
# 11615.199999999999
# 50
# 50
# Population's average fitness: -2982.42000 stdev: 4919.75613
# Best fitness: 11615.20000 - size: (5, 12520) - species 1 - id 2
# Average adjusted fitness: 0.411
# Mean genetic distance 1.010, standard deviation 0.157
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    0    50  11615.2    0.411     0
# Total extinctions: 0
# Generation time: 169.793 sec
#
#  ****** Running generation 1 ******
#
# 6
# 219660.80000000002
# 50
# 50
# Population's average fitness: -114902.84600 stdev: 99255.14905
# Best fitness: 219660.80000 - size: (5, 12460) - species 1 - id 56
#
# Best individual in generation 1 meets fitness threshold - complexity: (5, 12460)
#
# Best genome:
# Key: 56
# Fitness: 219660.80000000002
# Nodes:
# 	0 DefaultNodeGene(key=0, bias=-1.6846976108694907, response=1.0, activation=sigmoid, aggregation=sum)
# 	1 DefaultNodeGene(key=1, bias=0.11113176850117745, response=1.0, activation=sigmoid, aggregation=sum)
# 	2 DefaultNodeGene(key=2, bias=0.431124729392134, response=1.0, activation=sigmoid, aggregation=sum)
# 	3 DefaultNodeGene(key=3, bias=-0.15894604082549924, response=1.0, activation=sigmoid, aggregation=sum)
# 	4 DefaultNodeGene(key=4, bias=0.42844266026306865, response=1.0, activation=sigmoid, aggregation=sum)
# Connections:
# 	DefaultConnectionGene(key=(-2504, 0), weight=1.246880466197688, enabled=True)
# 	DefaultConnectionGene(key=(-2504, 1), weight=-0.837785761470034, enabled=True)
# 	DefaultConnectionGene(key=(-2504, 2), weight=0.37776649629657655, enabled=True)
# 	DefaultConnectionGene(key=(-2504, 3), weight=-0.5407633526584691, enabled=True)
# 	DefaultConnectionGene(key=(-2504, 4), weight=-2.6168868011823805, enabled=True)
# 	DefaultConnectionGene(key=(-2503, 0), weight=-0.054598228534588095, enabled=True)
# 	DefaultConnectionGene(key=(-2503, 1), weight=0.25365570626487843, enabled=True)
# 	DefaultConnectionGene(key=(-2503, 2), weight=1.589967792879444, enabled=True)
# 	DefaultConnectionGene(key=(-2503, 3), weight=-1.0837379905887217, enabled=True)
# 	DefaultConnectionGene(key=(-2503, 4), weight=-0.02330089991893282, enabled=True)
# 	DefaultConnectionGene(key=(-2502, 0), weight=-1.597851179536801, enabled=True)
# 	DefaultConnectionGene(key=(-2502, 1), weight=-0.4180803768762467, enabled=True)
# 	DefaultConnectionGene(key=(-2502, 2), weight=-0.9204047570111877, enabled=True)
# 	DefaultConnectionGene(key=(-2502, 3), weight=-0.5445218447002108, enabled=True)
# 	DefaultConnectionGene(key=(-2502, 4), weight=1.7003912944854647, enabled=True)
# 	DefaultConnectionGene(key=(-2501, 0), weight=-0.2330552370005848, enabled=True)
# 	DefaultConnectionGene(key=(-2501, 1), weight=-0.44814368617953365, enabled=True)
# 	DefaultConnectionGene(key=(-2501, 2), weight=-0.17262077406036666, enabled=True)
# 	DefaultConnectionGene(key=(-2501, 3), weight=0.6874473055763282, enabled=True)
# 	DefaultConnectionGene(key=(-2501, 4), weight=-0.14785946769838887, enabled=True)
# 	DefaultConnectionGene(key=(-2500, 0), weight=-0.11436327602957293, enabled=True)
# 	DefaultConnectionGene(key=(-2500, 1), weight=1.274430668494753, enabled=True)
# 	DefaultConnectionGene(key=(-2500, 2), weight=-0.38369028712086084, enabled=True)
# 	DefaultConnectionGene(key=(-2500, 3), weight=1.8680739616978932, enabled=True)
# 	DefaultConnectionGene(key=(-2500, 4), weight=-0.3887174090492358, enabled=True)
# 	DefaultConnectionGene(key=(-2499, 0), weight=0.11010412541382092, enabled=True)
# 	DefaultConnectionGene(key=(-2499, 1), weight=0.1722551367614722, enabled=True)
# 	DefaultConnectionGene(key=(-2499, 2), weight=-2.089219390015032, enabled=True)
# 	DefaultConnectionGene(key=(-2499, 3), weight=0.689012179487575, enabled=True)
# 	DefaultConnectionGene(key=(-2499, 4), weight=-0.780409088165174, enabled=True)
# 	DefaultConnectionGene(key=(-2498, 0), weight=1.7009522543789772, enabled=True)
# 	DefaultConnectionGene(key=(-2498, 1), weight=-0.5545439265206282, enabled=True)
# 	DefaultConnectionGene(key=(-2498, 2), weight=-0.1887573470489068, enabled=True)
# 	DefaultConnectionGene(key=(-2498, 3), weight=-0.3698213843342899, enabled=True)
# 	DefaultConnectionGene(key=(-2498, 4), weight=-0.3102718124416043, enabled=True)
# 	DefaultConnectionGene(key=(-2497, 0), weight=0.3549094660521178, enabled=True)
# 	DefaultConnectionGene(key=(-2497, 1), weight=0.8073704516445172, enabled=True)
# 	DefaultConnectionGene(key=(-2497, 2), weight=0.6584727914968738, enabled=True)
# 	DefaultConnectionGene(key=(-2497, 3), weight=0.17163964000575602, enabled=True)
# 	DefaultConnectionGene(key=(-2497, 4), weight=-1.0387080740391135, enabled=True)
# 	DefaultConnectionGene(key=(-2496, 0), weight=0.6691880795899877, enabled=True)
# 	DefaultConnectionGene(key=(-2496, 1), weight=-0.31328206479622434, enabled=True)
# 	DefaultConnectionGene(key=(-2496, 2), weight=1.1765010840851844, enabled=True)
# 	DefaultConnectionGene(key=(-2496, 3), weight=0.6392567944973614, enabled=True)
# 	DefaultConnectionGene(key=(-2496, 4), weight=1.0706397095649127, enabled=True)
# 	DefaultConnectionGene(key=(-2495, 0), weight=0.9179028826702555, enabled=True)
# 	DefaultConnectionGene(key=(-2495, 1), weight=0.6378418703101058, enabled=True)
# 	DefaultConnectionGene(key=(-2495, 2), weight=-0.8924100316700831, enabled=True)
# 	DefaultConnectionGene(key=(-2495, 3), weight=-0.6862839395427215, enabled=True)
# 	DefaultConnectionGene(key=(-2495, 4), weight=1.6345788605978309, enabled=True)
# 	DefaultConnectionGene(key=(-2494, 0), weight=-1.2900553661869774, enabled=True)
# 	DefaultConnectionGene(key=(-2494, 1), weight=-0.6874277082971537, enabled=True)
# 	DefaultConnectionGene(key=(-2494, 2), weight=-1.6858598096032482, enabled=True)
# 	DefaultConnectionGene(key=(-2494, 3), weight=0.04811046518088192, enabled=True)
# 	DefaultConnectionGene(key=(-2494, 4), weight=-2.9436468685821646, enabled=True)
# 	DefaultConnectionGene(key=(-2493, 0), weight=-0.3151750604721119, enabled=True)
# 	DefaultConnectionGene(key=(-2493, 1), weight=0.4250426707923184, enabled=True)
# 	DefaultConnectionGene(key=(-2493, 2), weight=1.6299672657239888, enabled=True)
# 	DefaultConnectionGene(key=(-2493, 3), weight=1.1603177167807712, enabled=True)
# 	DefaultConnectionGene(key=(-2493, 4), weight=-1.4560058112781888, enabled=True)
# 	DefaultConnectionGene(key=(-2492, 0), weight=-1.6379126871429885, enabled=True)
# 	DefaultConnectionGene(key=(-2492, 1), weight=-0.1893821070832337, enabled=True)
# 	DefaultConnectionGene(key=(-2492, 2), weight=-0.0069154761555996, enabled=True)
# 	DefaultConnectionGene(key=(-2492, 3), weight=0.35385490780439416, enabled=True)
# 	DefaultConnectionGene(key=(-2492, 4), weight=-0.5103810332594854, enabled=True)
# 	DefaultConnectionGene(key=(-2491, 0), weight=-0.3905081946863272, enabled=True)
# 	DefaultConnectionGene(key=(-2491, 1), weight=-1.1739708577015557, enabled=True)
# 	DefaultConnectionGene(key=(-2491, 2), weight=-1.2216042324240113, enabled=True)
# 	DefaultConnectionGene(key=(-2491, 3), weight=-0.09487761497592948, enabled=True)
# 	DefaultConnectionGene(key=(-2491, 4), weight=-1.7040650519213465, enabled=True)
# 	DefaultConnectionGene(key=(-2490, 0), weight=1.9432514778207688, enabled=True)
# 	DefaultConnectionGene(key=(-2490, 1), weight=-0.5528138810388701, enabled=True)
# 	DefaultConnectionGene(key=(-2490, 2), weight=-2.0494591943777882, enabled=True)
# 	DefaultConnectionGene(key=(-2490, 3), weight=-0.34396248910173477, enabled=True)
# 	DefaultConnectionGene(key=(-2490, 4), weight=0.5509365833358542, enabled=True)
# 	DefaultConnectionGene(key=(-2489, 0), weight=2.476202692328113, enabled=True)
# 	DefaultConnectionGene(key=(-2489, 1), weight=0.22760546142159432, enabled=True)
# 	DefaultConnectionGene(key=(-2489, 2), weight=-1.1193130798495936, enabled=True)
# 	DefaultConnectionGene(key=(-2489, 3), weight=0.8164119432098429, enabled=True)
# 	DefaultConnectionGene(key=(-2489, 4), weight=-0.10850558786437411, enabled=True)
# 	DefaultConnectionGene(key=(-2488, 0), weight=0.6457108277500528, enabled=True)
# 	DefaultConnectionGene(key=(-2488, 1), weight=0.7587831368976503, enabled=True)
# 	DefaultConnectionGene(key=(-2488, 2), weight=0.35380423799997734, enabled=True)
# 	DefaultConnectionGene(key=(-2488, 3), weight=-0.028703977858731466, enabled=True)
# 	DefaultConnectionGene(key=(-2488, 4), weight=1.0127345888595203, enabled=True)
# 	DefaultConnectionGene(key=(-2487, 0), weight=-0.7272389501495673, enabled=True)
# 	DefaultConnectionGene(key=(-2487, 1), weight=0.1135967652292896, enabled=True)
# 	DefaultConnectionGene(key=(-2487, 2), weight=0.0999625609968197, enabled=True)
# 	DefaultConnectionGene(key=(-2487, 3), weight=-0.17703894851569807, enabled=True)
# 	DefaultConnectionGene(key=(-2487, 4), weight=0.322169187847155, enabled=True)
# 	DefaultConnectionGene(key=(-2486, 0), weight=-0.19711404046629494, enabled=True)
# 	DefaultConnectionGene(key=(-2486, 1), weight=-0.641605628000465, enabled=True)
# 	DefaultConnectionGene(key=(-2486, 2), weight=-0.2838247345228052, enabled=True)
# 	DefaultConnectionGene(key=(-2486, 3), weight=0.5875549861114421, enabled=True)
# 	DefaultConnectionGene(key=(-2486, 4), weight=-2.218706363385658, enabled=True)
# 	DefaultConnectionGene(key=(-2485, 0), weight=-0.7498140574158698, enabled=True)
# 	DefaultConnectionGene(key=(-2485, 1), weight=-1.1212897711962118, enabled=True)
# 	DefaultConnectionGene(key=(-2485, 2), weight=0.189890890230878, enabled=True)
# 	DefaultConnectionGene(key=(-2485, 3), weight=-0.9287684700246541, enabled=True)
# 	DefaultConnectionGene(key=(-2485, 4), weight=-0.6803993440648184, enabled=True)
# 	DefaultConnectionGene(key=(-2484, 0), weight=-0.841806897858262, enabled=True)
# 	DefaultConnectionGene(key=(-2484, 1), weight=-2.2129844184900955, enabled=True)
# 	DefaultConnectionGene(key=(-2484, 2), weight=1.5870558911641148, enabled=True)
# 	DefaultConnectionGene(key=(-2484, 3), weight=-0.2381504669360558, enabled=True)
# 	DefaultConnectionGene(key=(-2484, 4), weight=1.1556903176059714, enabled=True)
# 	DefaultConnectionGene(key=(-2483, 0), weight=0.7694978203176349, enabled=True)
# 	DefaultConnectionGene(key=(-2483, 1), weight=1.5762566079303963, enabled=True)
# 	DefaultConnectionGene(key=(-2483, 2), weight=-0.060800993379694496, enabled=True)
# 	DefaultConnectionGene(key=(-2483, 3), weight=1.6057625950261014, enabled=True)
# 	DefaultConnectionGene(key=(-2483, 4), weight=-0.712033286781756, enabled=True)
# 	DefaultConnectionGene(key=(-2482, 0), weight=1.1499229458778677, enabled=True)
# 	DefaultConnectionGene(key=(-2482, 1), weight=-0.35128225023664483, enabled=True)
# 	DefaultConnectionGene(key=(-2482, 2), weight=0.15267493980660285, enabled=True)
# 	DefaultConnectionGene(key=(-2482, 3), weight=0.3048361907680095, enabled=True)
# 	DefaultConnectionGene(key=(-2482, 4), weight=-2.3001459220927063, enabled=True)
# 	DefaultConnectionGene(key=(-2481, 0), weight=0.06086466047521409, enabled=True)
# 	DefaultConnectionGene(key=(-2481, 1), weight=1.4000466429280238, enabled=True)
# 	DefaultConnectionGene(key=(-2481, 2), weight=0.7424885893369695, enabled=True)
# 	DefaultConnectionGene(key=(-2481, 3), weight=-0.75988596627652, enabled=True)
# 	DefaultConnectionGene(key=(-2481, 4), weight=-1.4434667832392167, enabled=True)
# 	DefaultConnectionGene(key=(-2480, 0), weight=-0.7386381083227325, enabled=True)
# 	DefaultConnectionGene(key=(-2480, 1), weight=0.0686431137880081, enabled=True)
# 	DefaultConnectionGene(key=(-2480, 2), weight=-0.9775180493666408, enabled=True)
# 	DefaultConnectionGene(key=(-2480, 3), weight=0.21055704665533437, enabled=True)
# 	DefaultConnectionGene(key=(-2480, 4), weight=-0.16425525688665146, enabled=True)
# 	DefaultConnectionGene(key=(-2479, 0), weight=-0.7470341663151914, enabled=True)
# 	DefaultConnectionGene(key=(-2479, 1), weight=-0.3513551678067576, enabled=True)
# 	DefaultConnectionGene(key=(-2479, 2), weight=-0.8725552183483751, enabled=True)
# 	DefaultConnectionGene(key=(-2479, 3), weight=-0.7713651816963639, enabled=True)
# 	DefaultConnectionGene(key=(-2479, 4), weight=-0.21461688774386214, enabled=True)
# 	DefaultConnectionGene(key=(-2478, 0), weight=0.09118128003679643, enabled=True)
# 	DefaultConnectionGene(key=(-2478, 1), weight=-1.4650700448170475, enabled=True)
# 	DefaultConnectionGene(key=(-2478, 2), weight=1.3407948325317376, enabled=True)
# 	DefaultConnectionGene(key=(-2478, 3), weight=-0.7524038410176276, enabled=True)
# 	DefaultConnectionGene(key=(-2478, 4), weight=0.31952644279929165, enabled=True)
# 	DefaultConnectionGene(key=(-2477, 0), weight=0.9949654732317762, enabled=True)
# 	DefaultConnectionGene(key=(-2477, 1), weight=1.1637664695058016, enabled=True)
# 	DefaultConnectionGene(key=(-2477, 2), weight=-0.8292027320457919, enabled=True)
# 	DefaultConnectionGene(key=(-2477, 3), weight=-1.0504772186086566, enabled=True)
# 	DefaultConnectionGene(key=(-2477, 4), weight=-0.026816347685886865, enabled=True)
# 	DefaultConnectionGene(key=(-2476, 0), weight=1.2268552904962935, enabled=True)
# 	DefaultConnectionGene(key=(-2476, 1), weight=0.6782074370117264, enabled=True)
# 	DefaultConnectionGene(key=(-2476, 2), weight=0.4406051168537608, enabled=True)
# 	DefaultConnectionGene(key=(-2476, 3), weight=-0.4682027595524023, enabled=True)
# 	DefaultConnectionGene(key=(-2476, 4), weight=1.185100800683009, enabled=True)
# 	DefaultConnectionGene(key=(-2475, 0), weight=-0.2636634096010002, enabled=True)
# 	DefaultConnectionGene(key=(-2475, 1), weight=-0.03824299168060096, enabled=True)
# 	DefaultConnectionGene(key=(-2475, 2), weight=-0.9773866023394497, enabled=True)
# 	DefaultConnectionGene(key=(-2475, 3), weight=-0.2717881352642948, enabled=True)
# 	DefaultConnectionGene(key=(-2475, 4), weight=-1.718879173990402, enabled=True)
# 	DefaultConnectionGene(key=(-2474, 0), weight=-0.5673064303584291, enabled=True)
# 	DefaultConnectionGene(key=(-2474, 1), weight=-0.9694248308303062, enabled=False)
# 	DefaultConnectionGene(key=(-2474, 2), weight=-1.4967847289536653, enabled=True)
# 	DefaultConnectionGene(key=(-2474, 3), weight=-0.22905133065817557, enabled=True)
# 	DefaultConnectionGene(key=(-2474, 4), weight=0.6697462156684445, enabled=True)
# 	DefaultConnectionGene(key=(-2473, 0), weight=-1.2849087766370206, enabled=True)
# 	DefaultConnectionGene(key=(-2473, 1), weight=0.437062098437219, enabled=True)
# 	DefaultConnectionGene(key=(-2473, 2), weight=-0.03344851043500496, enabled=True)
# 	DefaultConnectionGene(key=(-2473, 3), weight=1.0221078524573888, enabled=True)
# 	DefaultConnectionGene(key=(-2473, 4), weight=-0.5385992475082523, enabled=True)
# 	DefaultConnectionGene(key=(-2472, 0), weight=-0.16259356852888815, enabled=True)
# 	DefaultConnectionGene(key=(-2472, 1), weight=0.07551132050110512, enabled=True)
# 	DefaultConnectionGene(key=(-2472, 2), weight=-0.8795332585906901, enabled=True)
# 	DefaultConnectionGene(key=(-2472, 3), weight=-1.368502885929558, enabled=True)
# 	DefaultConnectionGene(key=(-2472, 4), weight=-0.009415737542759817, enabled=True)
# 	DefaultConnectionGene(key=(-2471, 0), weight=1.688053981471762, enabled=True)
# 	DefaultConnectionGene(key=(-2471, 1), weight=2.2205720815861882, enabled=True)
# 	DefaultConnectionGene(key=(-2471, 2), weight=-0.19378853392459916, enabled=True)
# 	DefaultConnectionGene(key=(-2471, 3), weight=0.10669920717562385, enabled=True)
# 	DefaultConnectionGene(key=(-2471, 4), weight=1.0764371032996864, enabled=True)
# 	DefaultConnectionGene(key=(-2470, 0), weight=-0.031137309956112802, enabled=True)
# 	DefaultConnectionGene(key=(-2470, 1), weight=-0.14226284866005434, enabled=True)
# 	DefaultConnectionGene(key=(-2470, 2), weight=-1.9972831127265926, enabled=True)
# 	DefaultConnectionGene(key=(-2470, 3), weight=0.7141389075050821, enabled=True)
# 	DefaultConnectionGene(key=(-2470, 4), weight=0.4652395913737335, enabled=True)
# 	DefaultConnectionGene(key=(-2469, 0), weight=-1.5766464040826547, enabled=True)
# 	DefaultConnectionGene(key=(-2469, 1), weight=2.344696659687834, enabled=True)
# 	DefaultConnectionGene(key=(-2469, 2), weight=2.3657631197197224, enabled=True)
# 	DefaultConnectionGene(key=(-2469, 3), weight=-0.6264338888061773, enabled=True)
# 	DefaultConnectionGene(key=(-2469, 4), weight=0.8276912859945849, enabled=True)
# 	DefaultConnectionGene(key=(-2468, 0), weight=0.37705401629885665, enabled=True)
# 	DefaultConnectionGene(key=(-2468, 1), weight=0.12015556012745762, enabled=True)
# 	DefaultConnectionGene(key=(-2468, 2), weight=0.47875797940694975, enabled=True)
# 	DefaultConnectionGene(key=(-2468, 3), weight=-1.8639894944093385, enabled=True)
# 	DefaultConnectionGene(key=(-2468, 4), weight=1.3783001370005612, enabled=True)
# 	DefaultConnectionGene(key=(-2467, 0), weight=-0.24031097523119987, enabled=True)
# 	DefaultConnectionGene(key=(-2467, 1), weight=-0.15340510120898382, enabled=True)
# 	DefaultConnectionGene(key=(-2467, 2), weight=1.2760262008639458, enabled=True)
# 	DefaultConnectionGene(key=(-2467, 3), weight=1.3229748666627557, enabled=True)
# 	DefaultConnectionGene(key=(-2467, 4), weight=-0.511886349038244, enabled=True)
# 	DefaultConnectionGene(key=(-2466, 0), weight=-1.0647171455512445, enabled=True)
# 	DefaultConnectionGene(key=(-2466, 1), weight=0.3800152700745503, enabled=True)
# 	DefaultConnectionGene(key=(-2466, 2), weight=1.5498551991076257, enabled=True)
# 	DefaultConnectionGene(key=(-2466, 3), weight=0.8644304467976409, enabled=True)
# 	DefaultConnectionGene(key=(-2466, 4), weight=-2.5592557048876374, enabled=True)
# 	DefaultConnectionGene(key=(-2465, 0), weight=-0.6463946908305163, enabled=True)
# 	DefaultConnectionGene(key=(-2465, 1), weight=-0.7747060989664997, enabled=True)
# 	DefaultConnectionGene(key=(-2465, 2), weight=-1.125266585152298, enabled=True)
# 	DefaultConnectionGene(key=(-2465, 3), weight=-1.6563225418172842, enabled=True)
# 	DefaultConnectionGene(key=(-2465, 4), weight=2.3897267654969423, enabled=True)
# 	DefaultConnectionGene(key=(-2464, 0), weight=-0.831112627268652, enabled=True)
# 	DefaultConnectionGene(key=(-2464, 1), weight=-0.20002792173939687, enabled=True)
# 	DefaultConnectionGene(key=(-2464, 2), weight=1.2484940336874926, enabled=True)
# 	DefaultConnectionGene(key=(-2464, 3), weight=-0.9799003617899849, enabled=True)
# 	DefaultConnectionGene(key=(-2464, 4), weight=0.17579039039579292, enabled=False)
# 	DefaultConnectionGene(key=(-2463, 0), weight=0.6922068503855734, enabled=True)
# 	DefaultConnectionGene(key=(-2463, 1), weight=3.8681107034978246, enabled=True)
# 	DefaultConnectionGene(key=(-2463, 2), weight=1.3240597481236602, enabled=True)
# 	DefaultConnectionGene(key=(-2463, 3), weight=0.11526941001704594, enabled=True)
# 	DefaultConnectionGene(key=(-2463, 4), weight=0.3357531613324571, enabled=True)
# 	DefaultConnectionGene(key=(-2462, 0), weight=-0.4142756809887311, enabled=True)
# 	DefaultConnectionGene(key=(-2462, 1), weight=-0.8653649834110129, enabled=True)
# 	DefaultConnectionGene(key=(-2462, 2), weight=1.0002983684837166, enabled=True)
# 	DefaultConnectionGene(key=(-2462, 3), weight=1.4383355937091027, enabled=True)
# 	DefaultConnectionGene(key=(-2462, 4), weight=0.43621334566798164, enabled=True)
# 	DefaultConnectionGene(key=(-2461, 0), weight=-0.5126495045911971, enabled=True)
# 	DefaultConnectionGene(key=(-2461, 1), weight=3.2114180082346837, enabled=True)
# 	DefaultConnectionGene(key=(-2461, 2), weight=-0.9099573393493882, enabled=True)
# 	DefaultConnectionGene(key=(-2461, 3), weight=0.3818883802446878, enabled=True)
# 	DefaultConnectionGene(key=(-2461, 4), weight=1.250325395461794, enabled=True)
# 	DefaultConnectionGene(key=(-2460, 0), weight=1.6912855396069155, enabled=True)
# 	DefaultConnectionGene(key=(-2460, 1), weight=0.9639479896207896, enabled=True)
# 	DefaultConnectionGene(key=(-2460, 2), weight=1.071044553172866, enabled=True)
# 	DefaultConnectionGene(key=(-2460, 3), weight=-0.015460928852487024, enabled=True)
# 	DefaultConnectionGene(key=(-2460, 4), weight=-0.9086292826732815, enabled=True)
# 	DefaultConnectionGene(key=(-2459, 0), weight=-1.4139800740298583, enabled=True)
# 	DefaultConnectionGene(key=(-2459, 1), weight=-1.8252483382349416, enabled=True)
# 	DefaultConnectionGene(key=(-2459, 2), weight=-1.1053372386146763, enabled=True)
# 	DefaultConnectionGene(key=(-2459, 3), weight=-0.3114107062970256, enabled=True)
# 	DefaultConnectionGene(key=(-2459, 4), weight=-0.3910125753249191, enabled=True)
# 	DefaultConnectionGene(key=(-2458, 0), weight=1.3975507482726082, enabled=True)
# 	DefaultConnectionGene(key=(-2458, 1), weight=-1.2125161716436237, enabled=True)
# 	DefaultConnectionGene(key=(-2458, 2), weight=-1.5595498387651594, enabled=True)
# 	DefaultConnectionGene(key=(-2458, 3), weight=-1.8109012772057775, enabled=True)
# 	DefaultConnectionGene(key=(-2458, 4), weight=1.8810857193563135, enabled=True)
# 	DefaultConnectionGene(key=(-2457, 0), weight=-1.3465498153889341, enabled=True)
# 	DefaultConnectionGene(key=(-2457, 1), weight=2.128263433392775, enabled=True)
# 	DefaultConnectionGene(key=(-2457, 2), weight=0.11559609997252229, enabled=True)
# 	DefaultConnectionGene(key=(-2457, 3), weight=-1.4999159948105965, enabled=True)
# 	DefaultConnectionGene(key=(-2457, 4), weight=1.6687692450111082, enabled=True)
# 	DefaultConnectionGene(key=(-2456, 0), weight=-1.0245649073125127, enabled=True)
# 	DefaultConnectionGene(key=(-2456, 1), weight=1.760126570875781, enabled=True)
# 	DefaultConnectionGene(key=(-2456, 2), weight=-0.06865418799562031, enabled=True)
# 	DefaultConnectionGene(key=(-2456, 3), weight=0.5492756043780552, enabled=True)
# 	DefaultConnectionGene(key=(-2456, 4), weight=1.596107077039271, enabled=True)
# 	DefaultConnectionGene(key=(-2455, 0), weight=-1.1159078238956974, enabled=True)
# 	DefaultConnectionGene(key=(-2455, 1), weight=0.1300065473229741, enabled=True)
# 	DefaultConnectionGene(key=(-2455, 2), weight=0.3869018835986133, enabled=True)
# 	DefaultConnectionGene(key=(-2455, 3), weight=1.8196912492982797, enabled=True)
# 	DefaultConnectionGene(key=(-2455, 4), weight=0.9362238816863686, enabled=True)
# 	DefaultConnectionGene(key=(-2454, 0), weight=-0.5756208905705437, enabled=True)
# 	DefaultConnectionGene(key=(-2454, 1), weight=-1.3286562134017923, enabled=True)
# 	DefaultConnectionGene(key=(-2454, 2), weight=0.8512177238642911, enabled=True)
# 	DefaultConnectionGene(key=(-2454, 3), weight=-0.6202940281487612, enabled=True)
# 	DefaultConnectionGene(key=(-2454, 4), weight=1.1323280422114441, enabled=True)
# 	DefaultConnectionGene(key=(-2453, 0), weight=1.042896547112313, enabled=True)
# 	DefaultConnectionGene(key=(-2453, 1), weight=-1.339628028213654, enabled=True)
# 	DefaultConnectionGene(key=(-2453, 2), weight=1.504773709737271, enabled=True)
# 	DefaultConnectionGene(key=(-2453, 3), weight=0.1440337997396849, enabled=True)
# 	DefaultConnectionGene(key=(-2453, 4), weight=-0.32707922584963955, enabled=True)
# 	DefaultConnectionGene(key=(-2452, 0), weight=1.3211710379796704, enabled=True)
# 	DefaultConnectionGene(key=(-2452, 1), weight=0.12260317979593682, enabled=True)
# 	DefaultConnectionGene(key=(-2452, 2), weight=-1.3660292619423164, enabled=True)
# 	DefaultConnectionGene(key=(-2452, 3), weight=-0.8705072959072337, enabled=True)
# 	DefaultConnectionGene(key=(-2452, 4), weight=0.8132188902606818, enabled=True)
# 	DefaultConnectionGene(key=(-2451, 0), weight=1.33043798242992, enabled=True)
# 	DefaultConnectionGene(key=(-2451, 1), weight=0.017810459107427786, enabled=True)
# 	DefaultConnectionGene(key=(-2451, 2), weight=0.9024501561900989, enabled=True)
# 	DefaultConnectionGene(key=(-2451, 3), weight=-1.4487738121291938, enabled=True)
# 	DefaultConnectionGene(key=(-2451, 4), weight=0.5840639319119476, enabled=True)
# 	DefaultConnectionGene(key=(-2450, 0), weight=0.5336509734366168, enabled=True)
# 	DefaultConnectionGene(key=(-2450, 1), weight=-0.5792213426576851, enabled=True)
# 	DefaultConnectionGene(key=(-2450, 2), weight=-1.0850850954510838, enabled=True)
# 	DefaultConnectionGene(key=(-2450, 3), weight=-2.1319553893690157, enabled=True)
# 	DefaultConnectionGene(key=(-2450, 4), weight=0.4003702722378101, enabled=True)
# 	DefaultConnectionGene(key=(-2449, 0), weight=-0.7852648528392475, enabled=True)
# 	DefaultConnectionGene(key=(-2449, 1), weight=1.2072832733407837, enabled=True)
# 	DefaultConnectionGene(key=(-2449, 2), weight=0.3920984991248305, enabled=True)
# 	DefaultConnectionGene(key=(-2449, 3), weight=1.1389580195524553, enabled=True)
# 	DefaultConnectionGene(key=(-2449, 4), weight=-1.1689606876164735, enabled=True)
# 	DefaultConnectionGene(key=(-2448, 0), weight=-0.678358237483733, enabled=True)
# 	DefaultConnectionGene(key=(-2448, 1), weight=1.474578518690035, enabled=True)
# 	DefaultConnectionGene(key=(-2448, 2), weight=0.4514220773097075, enabled=True)
# 	DefaultConnectionGene(key=(-2448, 3), weight=0.8307709666436539, enabled=True)
# 	DefaultConnectionGene(key=(-2448, 4), weight=-0.8370097806622989, enabled=True)
# 	DefaultConnectionGene(key=(-2447, 0), weight=-1.0697911183329605, enabled=True)
# 	DefaultConnectionGene(key=(-2447, 1), weight=0.08200751880792179, enabled=True)
# 	DefaultConnectionGene(key=(-2447, 2), weight=-1.1769619596499798, enabled=True)
# 	DefaultConnectionGene(key=(-2447, 3), weight=0.08257767136033442, enabled=True)
# 	DefaultConnectionGene(key=(-2447, 4), weight=-2.284911730342596, enabled=True)
# 	DefaultConnectionGene(key=(-2446, 0), weight=-1.3161501985452306, enabled=True)
# 	DefaultConnectionGene(key=(-2446, 1), weight=-0.48925597847094626, enabled=True)
# 	DefaultConnectionGene(key=(-2446, 2), weight=0.23124511510338241, enabled=True)
# 	DefaultConnectionGene(key=(-2446, 3), weight=-0.2728150153711709, enabled=True)
# 	DefaultConnectionGene(key=(-2446, 4), weight=0.6259224065611451, enabled=True)
# 	DefaultConnectionGene(key=(-2445, 0), weight=1.0370687278886952, enabled=True)
# 	DefaultConnectionGene(key=(-2445, 1), weight=-0.9835061590289016, enabled=True)
# 	DefaultConnectionGene(key=(-2445, 2), weight=-0.621681787249827, enabled=True)
# 	DefaultConnectionGene(key=(-2445, 3), weight=-2.522931183381606, enabled=True)
# 	DefaultConnectionGene(key=(-2445, 4), weight=-0.11124538433576414, enabled=True)
# 	DefaultConnectionGene(key=(-2444, 0), weight=0.6180654307288346, enabled=True)
# 	DefaultConnectionGene(key=(-2444, 1), weight=0.5802179508916476, enabled=True)
# 	DefaultConnectionGene(key=(-2444, 2), weight=-0.08955096118962924, enabled=True)
# 	DefaultConnectionGene(key=(-2444, 3), weight=-0.763778912846589, enabled=True)
# 	DefaultConnectionGene(key=(-2444, 4), weight=1.0825448783565987, enabled=True)
# 	DefaultConnectionGene(key=(-2443, 0), weight=1.821624951250956, enabled=True)
# 	DefaultConnectionGene(key=(-2443, 1), weight=-1.1401895587304025, enabled=True)
# 	DefaultConnectionGene(key=(-2443, 2), weight=-0.5607172042023765, enabled=True)
# 	DefaultConnectionGene(key=(-2443, 3), weight=-2.033395476900506, enabled=True)
# 	DefaultConnectionGene(key=(-2443, 4), weight=0.8679139547687406, enabled=True)
# 	DefaultConnectionGene(key=(-2442, 0), weight=1.4217698195588429, enabled=True)
# 	DefaultConnectionGene(key=(-2442, 1), weight=-0.6659411348569207, enabled=True)
# 	DefaultConnectionGene(key=(-2442, 2), weight=0.1062127787971418, enabled=True)
# 	DefaultConnectionGene(key=(-2442, 3), weight=0.22976870605165134, enabled=True)
# 	DefaultConnectionGene(key=(-2442, 4), weight=-0.8691702712153662, enabled=True)
# 	DefaultConnectionGene(key=(-2441, 0), weight=-0.23278851429447228, enabled=True)
# 	DefaultConnectionGene(key=(-2441, 1), weight=-0.8330218645659824, enabled=True)
# 	DefaultConnectionGene(key=(-2441, 2), weight=-0.6742763604791084, enabled=True)
# 	DefaultConnectionGene(key=(-2441, 3), weight=1.4764546217154977, enabled=True)
# 	DefaultConnectionGene(key=(-2441, 4), weight=-0.548405283248342, enabled=True)
# 	DefaultConnectionGene(key=(-2440, 0), weight=-0.2834628282406587, enabled=True)
# 	DefaultConnectionGene(key=(-2440, 1), weight=1.3693179349342761, enabled=True)
# 	DefaultConnectionGene(key=(-2440, 2), weight=2.5317007531152456, enabled=True)
# 	DefaultConnectionGene(key=(-2440, 3), weight=-1.7907535785034687, enabled=True)
# 	DefaultConnectionGene(key=(-2440, 4), weight=-0.5925190231077566, enabled=True)
# 	DefaultConnectionGene(key=(-2439, 0), weight=-0.887237334916884, enabled=True)
# 	DefaultConnectionGene(key=(-2439, 1), weight=-0.4508477482919085, enabled=True)
# 	DefaultConnectionGene(key=(-2439, 2), weight=-2.2480273954977195, enabled=True)
# 	DefaultConnectionGene(key=(-2439, 3), weight=-0.3570026596044836, enabled=True)
# 	DefaultConnectionGene(key=(-2439, 4), weight=1.3362095281627409, enabled=True)
# 	DefaultConnectionGene(key=(-2438, 0), weight=1.7346457814403027, enabled=True)
# 	DefaultConnectionGene(key=(-2438, 1), weight=0.25739432324855577, enabled=True)
# 	DefaultConnectionGene(key=(-2438, 2), weight=1.1290546344784667, enabled=True)
# 	DefaultConnectionGene(key=(-2438, 3), weight=-0.2550727437605827, enabled=True)
# 	DefaultConnectionGene(key=(-2438, 4), weight=-1.1739434153075599, enabled=True)
# 	DefaultConnectionGene(key=(-2437, 0), weight=-0.04968638530402085, enabled=True)
# 	DefaultConnectionGene(key=(-2437, 1), weight=-0.7639528459631779, enabled=True)
# 	DefaultConnectionGene(key=(-2437, 2), weight=1.0686996714448103, enabled=True)
# 	DefaultConnectionGene(key=(-2437, 3), weight=0.4393360161613088, enabled=True)
# 	DefaultConnectionGene(key=(-2437, 4), weight=0.014887806376712932, enabled=True)
# 	DefaultConnectionGene(key=(-2436, 0), weight=-0.802004222008686, enabled=True)
# 	DefaultConnectionGene(key=(-2436, 1), weight=-1.0260095960848972, enabled=True)
# 	DefaultConnectionGene(key=(-2436, 2), weight=-0.8481079567597636, enabled=True)
# 	DefaultConnectionGene(key=(-2436, 3), weight=0.06546605008508011, enabled=True)
# 	DefaultConnectionGene(key=(-2436, 4), weight=0.47351819877046253, enabled=True)
# 	DefaultConnectionGene(key=(-2435, 0), weight=-1.1080387870240869, enabled=True)
# 	DefaultConnectionGene(key=(-2435, 1), weight=-2.6023237447501915, enabled=True)
# 	DefaultConnectionGene(key=(-2435, 2), weight=0.477942379852712, enabled=True)
# 	DefaultConnectionGene(key=(-2435, 3), weight=-0.3385060371500181, enabled=True)
# 	DefaultConnectionGene(key=(-2435, 4), weight=-0.16606426920450312, enabled=True)
# 	DefaultConnectionGene(key=(-2434, 0), weight=-0.27070154122264894, enabled=True)
# 	DefaultConnectionGene(key=(-2434, 1), weight=1.7991433851591165, enabled=True)
# 	DefaultConnectionGene(key=(-2434, 2), weight=0.11635947902186677, enabled=True)
# 	DefaultConnectionGene(key=(-2434, 3), weight=-0.2380734585825508, enabled=True)
# 	DefaultConnectionGene(key=(-2434, 4), weight=2.8605211377670994, enabled=True)
# 	DefaultConnectionGene(key=(-2433, 0), weight=-0.7079471308646516, enabled=True)
# 	DefaultConnectionGene(key=(-2433, 1), weight=1.9051765276131398, enabled=True)
# 	DefaultConnectionGene(key=(-2433, 2), weight=0.08182230352023118, enabled=True)
# 	DefaultConnectionGene(key=(-2433, 3), weight=0.2086358860371585, enabled=True)
# 	DefaultConnectionGene(key=(-2433, 4), weight=-1.714035534207373, enabled=True)
# 	DefaultConnectionGene(key=(-2432, 0), weight=-2.113286670513199, enabled=True)
# 	DefaultConnectionGene(key=(-2432, 1), weight=-0.46157699197552826, enabled=True)
# 	DefaultConnectionGene(key=(-2432, 2), weight=0.9481081548911193, enabled=True)
# 	DefaultConnectionGene(key=(-2432, 3), weight=-0.828889053211751, enabled=True)
# 	DefaultConnectionGene(key=(-2432, 4), weight=-1.6124597343805633, enabled=True)
# 	DefaultConnectionGene(key=(-2431, 0), weight=-0.12815148600424686, enabled=True)
# 	DefaultConnectionGene(key=(-2431, 1), weight=-0.3508063961528041, enabled=True)
# 	DefaultConnectionGene(key=(-2431, 2), weight=-0.45491281008236073, enabled=True)
# 	DefaultConnectionGene(key=(-2431, 3), weight=-0.4854174474025821, enabled=True)
# 	DefaultConnectionGene(key=(-2431, 4), weight=0.015500328696575583, enabled=True)
# 	DefaultConnectionGene(key=(-2430, 0), weight=0.3299869463850837, enabled=True)
# 	DefaultConnectionGene(key=(-2430, 1), weight=1.036751447248827, enabled=True)
# 	DefaultConnectionGene(key=(-2430, 2), weight=0.18391429210604526, enabled=True)
# 	DefaultConnectionGene(key=(-2430, 3), weight=-0.7015217588205421, enabled=True)
# 	DefaultConnectionGene(key=(-2430, 4), weight=0.5731426531538046, enabled=True)
# 	DefaultConnectionGene(key=(-2429, 0), weight=-0.8608481281661331, enabled=True)
# 	DefaultConnectionGene(key=(-2429, 1), weight=-0.37680451529113634, enabled=True)
# 	DefaultConnectionGene(key=(-2429, 2), weight=0.9375245434645733, enabled=True)
# 	DefaultConnectionGene(key=(-2429, 3), weight=1.1115278237635664, enabled=True)
# 	DefaultConnectionGene(key=(-2429, 4), weight=-1.428288508718461, enabled=True)
# 	DefaultConnectionGene(key=(-2428, 0), weight=2.4014618189412067, enabled=True)
# 	DefaultConnectionGene(key=(-2428, 1), weight=0.17617031235992683, enabled=True)
# 	DefaultConnectionGene(key=(-2428, 2), weight=2.252834490707806, enabled=True)
# 	DefaultConnectionGene(key=(-2428, 3), weight=0.5235894774535585, enabled=True)
# 	DefaultConnectionGene(key=(-2428, 4), weight=1.6663796849239585, enabled=True)
# 	DefaultConnectionGene(key=(-2427, 0), weight=-0.18277917329834742, enabled=True)
# 	DefaultConnectionGene(key=(-2427, 1), weight=-0.2603464161831752, enabled=True)
# 	DefaultConnectionGene(key=(-2427, 2), weight=-2.5805264402044834, enabled=True)
# 	DefaultConnectionGene(key=(-2427, 3), weight=1.417836041884419, enabled=True)
# 	DefaultConnectionGene(key=(-2427, 4), weight=-0.8041370165206836, enabled=True)
# 	DefaultConnectionGene(key=(-2426, 0), weight=1.5292953286877078, enabled=True)
# 	DefaultConnectionGene(key=(-2426, 1), weight=1.5035584438520044, enabled=True)
# 	DefaultConnectionGene(key=(-2426, 2), weight=-0.35220634598567724, enabled=True)
# 	DefaultConnectionGene(key=(-2426, 3), weight=-0.08222480812135236, enabled=True)
# 	DefaultConnectionGene(key=(-2426, 4), weight=-0.20748069941877645, enabled=True)
# 	DefaultConnectionGene(key=(-2425, 0), weight=1.140560048166785, enabled=True)
# 	DefaultConnectionGene(key=(-2425, 1), weight=-0.26052733926410987, enabled=True)
# 	DefaultConnectionGene(key=(-2425, 2), weight=0.5054615025606111, enabled=True)
# 	DefaultConnectionGene(key=(-2425, 3), weight=0.42264295401566226, enabled=True)
# 	DefaultConnectionGene(key=(-2425, 4), weight=0.2927165861429359, enabled=True)
# 	DefaultConnectionGene(key=(-2424, 0), weight=0.3119742718398435, enabled=True)
# 	DefaultConnectionGene(key=(-2424, 1), weight=-0.756176182086368, enabled=True)
# 	DefaultConnectionGene(key=(-2424, 2), weight=-0.07342597622893055, enabled=True)
# 	DefaultConnectionGene(key=(-2424, 3), weight=1.194301091612439, enabled=True)
# 	DefaultConnectionGene(key=(-2424, 4), weight=0.08539007405048982, enabled=True)
# 	DefaultConnectionGene(key=(-2423, 0), weight=0.9608322022426171, enabled=True)
# 	DefaultConnectionGene(key=(-2423, 1), weight=-0.6284040123853654, enabled=True)
# 	DefaultConnectionGene(key=(-2423, 2), weight=1.8601174656433268, enabled=True)
# 	DefaultConnectionGene(key=(-2423, 3), weight=1.5608101158236014, enabled=True)
# 	DefaultConnectionGene(key=(-2423, 4), weight=-0.5145223052907063, enabled=True)
# 	DefaultConnectionGene(key=(-2422, 0), weight=-0.6899972375790991, enabled=True)
# 	DefaultConnectionGene(key=(-2422, 1), weight=-0.2062463889366482, enabled=True)
# 	DefaultConnectionGene(key=(-2422, 2), weight=0.7693389819921621, enabled=True)
# 	DefaultConnectionGene(key=(-2422, 3), weight=-0.8236601264160646, enabled=True)
# 	DefaultConnectionGene(key=(-2422, 4), weight=-0.39706204206413476, enabled=True)
# 	DefaultConnectionGene(key=(-2421, 0), weight=-0.7438301125591559, enabled=True)
# 	DefaultConnectionGene(key=(-2421, 1), weight=1.485358284764798, enabled=True)
# 	DefaultConnectionGene(key=(-2421, 2), weight=-2.5375767602117416, enabled=True)
# 	DefaultConnectionGene(key=(-2421, 3), weight=0.2526458814007061, enabled=True)
# 	DefaultConnectionGene(key=(-2421, 4), weight=-0.6641652461263577, enabled=True)
# 	DefaultConnectionGene(key=(-2420, 0), weight=-0.14617249158915954, enabled=True)
# 	DefaultConnectionGene(key=(-2420, 1), weight=1.4204635669132888, enabled=True)
# 	DefaultConnectionGene(key=(-2420, 2), weight=0.9736285850465759, enabled=True)
# 	DefaultConnectionGene(key=(-2420, 3), weight=0.6256174410616645, enabled=True)
# 	DefaultConnectionGene(key=(-2420, 4), weight=-0.5655828177029618, enabled=True)
# 	DefaultConnectionGene(key=(-2419, 0), weight=1.1089586341480604, enabled=True)
# 	DefaultConnectionGene(key=(-2419, 1), weight=-0.337809590970902, enabled=True)
# 	DefaultConnectionGene(key=(-2419, 2), weight=-0.30690741724353654, enabled=True)
# 	DefaultConnectionGene(key=(-2419, 3), weight=-1.4870300444990971, enabled=True)
# 	DefaultConnectionGene(key=(-2419, 4), weight=-0.39649901754414507, enabled=True)
# 	DefaultConnectionGene(key=(-2418, 0), weight=0.2326224930069182, enabled=True)
# 	DefaultConnectionGene(key=(-2418, 1), weight=-0.11761322032597549, enabled=True)
# 	DefaultConnectionGene(key=(-2418, 2), weight=-0.5740731471014721, enabled=True)
# 	DefaultConnectionGene(key=(-2418, 3), weight=-0.6962541041487748, enabled=True)
# 	DefaultConnectionGene(key=(-2418, 4), weight=-0.7573268950083467, enabled=True)
# 	DefaultConnectionGene(key=(-2417, 0), weight=-0.4041202191374572, enabled=True)
# 	DefaultConnectionGene(key=(-2417, 1), weight=0.19542200230409343, enabled=True)
# 	DefaultConnectionGene(key=(-2417, 2), weight=-1.1280971139751592, enabled=True)
# 	DefaultConnectionGene(key=(-2417, 3), weight=-0.8674077491625084, enabled=True)
# 	DefaultConnectionGene(key=(-2417, 4), weight=-0.9806433832563186, enabled=True)
# 	DefaultConnectionGene(key=(-2416, 0), weight=2.149109380829297, enabled=True)
# 	DefaultConnectionGene(key=(-2416, 1), weight=0.2641113071077015, enabled=True)
# 	DefaultConnectionGene(key=(-2416, 2), weight=2.147585280262896, enabled=True)
# 	DefaultConnectionGene(key=(-2416, 3), weight=0.38884530717583254, enabled=True)
# 	DefaultConnectionGene(key=(-2416, 4), weight=0.2340393899128519, enabled=True)
# 	DefaultConnectionGene(key=(-2415, 0), weight=0.5462989097845241, enabled=True)
# 	DefaultConnectionGene(key=(-2415, 1), weight=-1.580466189371974, enabled=True)
# 	DefaultConnectionGene(key=(-2415, 2), weight=2.0306966014367975, enabled=True)
# 	DefaultConnectionGene(key=(-2415, 3), weight=-1.0991443798593457, enabled=True)
# 	DefaultConnectionGene(key=(-2415, 4), weight=0.5171101186975748, enabled=True)
# 	DefaultConnectionGene(key=(-2414, 0), weight=1.1170649630865899, enabled=True)
# 	DefaultConnectionGene(key=(-2414, 1), weight=-1.4042628210431018, enabled=True)
# 	DefaultConnectionGene(key=(-2414, 2), weight=0.6158915420379325, enabled=True)
# 	DefaultConnectionGene(key=(-2414, 3), weight=2.5473979452808364, enabled=True)
# 	DefaultConnectionGene(key=(-2414, 4), weight=0.35715752983733157, enabled=True)
# 	DefaultConnectionGene(key=(-2413, 0), weight=1.3672649701327493, enabled=True)
# 	DefaultConnectionGene(key=(-2413, 1), weight=0.6323444270905297, enabled=True)
# 	DefaultConnectionGene(key=(-2413, 2), weight=0.2546185813796835, enabled=True)
# 	DefaultConnectionGene(key=(-2413, 3), weight=-0.45645517092990234, enabled=True)
# 	DefaultConnectionGene(key=(-2413, 4), weight=1.089773540090978, enabled=True)
# 	DefaultConnectionGene(key=(-2412, 0), weight=-0.7242857116551589, enabled=True)
# 	DefaultConnectionGene(key=(-2412, 1), weight=0.6904458738909028, enabled=True)
# 	DefaultConnectionGene(key=(-2412, 2), weight=-0.8599451533959994, enabled=True)
# 	DefaultConnectionGene(key=(-2412, 3), weight=-0.7394762822561979, enabled=True)
# 	DefaultConnectionGene(key=(-2412, 4), weight=2.1155884884327105, enabled=True)
# 	DefaultConnectionGene(key=(-2411, 0), weight=-0.3114628127768144, enabled=True)
# 	DefaultConnectionGene(key=(-2411, 1), weight=0.9122611046925699, enabled=True)
# 	DefaultConnectionGene(key=(-2411, 2), weight=0.03308315284731689, enabled=True)
# 	DefaultConnectionGene(key=(-2411, 3), weight=-1.2880299024873292, enabled=True)
# 	DefaultConnectionGene(key=(-2411, 4), weight=2.168377635388952, enabled=True)
# 	DefaultConnectionGene(key=(-2410, 0), weight=-0.3150876741074262, enabled=True)
# 	DefaultConnectionGene(key=(-2410, 1), weight=0.12071579803944718, enabled=True)
# 	DefaultConnectionGene(key=(-2410, 2), weight=1.5811341880291194, enabled=True)
# 	DefaultConnectionGene(key=(-2410, 3), weight=1.1877676903598355, enabled=True)
# 	DefaultConnectionGene(key=(-2410, 4), weight=-0.17713418066615894, enabled=True)
# 	DefaultConnectionGene(key=(-2409, 0), weight=-0.2033065427944556, enabled=True)
# 	DefaultConnectionGene(key=(-2409, 1), weight=0.8255560467686089, enabled=True)
# 	DefaultConnectionGene(key=(-2409, 2), weight=-0.16061489171994064, enabled=True)
# 	DefaultConnectionGene(key=(-2409, 3), weight=0.7987261827173276, enabled=True)
# 	DefaultConnectionGene(key=(-2409, 4), weight=-1.1162412479586343, enabled=True)
# 	DefaultConnectionGene(key=(-2408, 0), weight=-1.2788492530506923, enabled=True)
# 	DefaultConnectionGene(key=(-2408, 1), weight=-0.33320384102947814, enabled=True)
# 	DefaultConnectionGene(key=(-2408, 2), weight=0.8653087274693022, enabled=True)
# 	DefaultConnectionGene(key=(-2408, 3), weight=1.05923043126585, enabled=True)
# 	DefaultConnectionGene(key=(-2408, 4), weight=1.108861794861065, enabled=True)
# 	DefaultConnectionGene(key=(-2407, 0), weight=1.3049891076940172, enabled=True)
# 	DefaultConnectionGene(key=(-2407, 1), weight=0.20020128414721472, enabled=True)
# 	DefaultConnectionGene(key=(-2407, 2), weight=1.5051705857117503, enabled=True)
# 	DefaultConnectionGene(key=(-2407, 3), weight=-0.4496024796559531, enabled=True)
# 	DefaultConnectionGene(key=(-2407, 4), weight=1.5202958124081702, enabled=True)
# 	DefaultConnectionGene(key=(-2406, 0), weight=0.722039223499916, enabled=True)
# 	DefaultConnectionGene(key=(-2406, 1), weight=-0.4928741230937326, enabled=True)
# 	DefaultConnectionGene(key=(-2406, 2), weight=-0.4189016393260747, enabled=True)
# 	DefaultConnectionGene(key=(-2406, 3), weight=-0.04300290616369373, enabled=True)
# 	DefaultConnectionGene(key=(-2406, 4), weight=-0.9894421224205917, enabled=True)
# 	DefaultConnectionGene(key=(-2405, 0), weight=1.2880601687979911, enabled=True)
# 	DefaultConnectionGene(key=(-2405, 1), weight=1.778126541420794, enabled=True)
# 	DefaultConnectionGene(key=(-2405, 2), weight=-1.806125692652602, enabled=True)
# 	DefaultConnectionGene(key=(-2405, 3), weight=1.4490707957237585, enabled=True)
# 	DefaultConnectionGene(key=(-2405, 4), weight=1.4699105372402246, enabled=True)
# 	DefaultConnectionGene(key=(-2404, 0), weight=1.2996770381105867, enabled=True)
# 	DefaultConnectionGene(key=(-2404, 1), weight=1.3968331392128028, enabled=True)
# 	DefaultConnectionGene(key=(-2404, 2), weight=-1.2447685044543304, enabled=True)
# 	DefaultConnectionGene(key=(-2404, 3), weight=-0.16834819781364813, enabled=True)
# 	DefaultConnectionGene(key=(-2404, 4), weight=0.6964802040201123, enabled=True)
# 	DefaultConnectionGene(key=(-2403, 0), weight=1.0796646666248817, enabled=True)
# 	DefaultConnectionGene(key=(-2403, 1), weight=0.08732217312887565, enabled=True)
# 	DefaultConnectionGene(key=(-2403, 2), weight=0.7134506819581596, enabled=True)
# 	DefaultConnectionGene(key=(-2403, 3), weight=-0.9038110374348807, enabled=True)
# 	DefaultConnectionGene(key=(-2403, 4), weight=-0.5945684972788119, enabled=True)
# 	DefaultConnectionGene(key=(-2402, 0), weight=-0.7672097732931654, enabled=True)
# 	DefaultConnectionGene(key=(-2402, 1), weight=0.017106754742525265, enabled=True)
# 	DefaultConnectionGene(key=(-2402, 2), weight=1.1466767989422286, enabled=True)
# 	DefaultConnectionGene(key=(-2402, 3), weight=-1.4040188483983664, enabled=True)
# 	DefaultConnectionGene(key=(-2402, 4), weight=-2.181882933432388, enabled=True)
# 	DefaultConnectionGene(key=(-2401, 0), weight=-0.9513378598896104, enabled=True)
# 	DefaultConnectionGene(key=(-2401, 1), weight=-0.9688009779545822, enabled=True)
# 	DefaultConnectionGene(key=(-2401, 2), weight=-0.3596571162119683, enabled=True)
# 	DefaultConnectionGene(key=(-2401, 3), weight=-1.413036482010845, enabled=True)
# 	DefaultConnectionGene(key=(-2401, 4), weight=0.2584420687649378, enabled=True)
# 	DefaultConnectionGene(key=(-2400, 0), weight=-1.1468665837945418, enabled=True)
# 	DefaultConnectionGene(key=(-2400, 1), weight=-1.705667594394746, enabled=True)
# 	DefaultConnectionGene(key=(-2400, 2), weight=0.5357021488487637, enabled=True)
# 	DefaultConnectionGene(key=(-2400, 3), weight=0.7113393290503031, enabled=True)
# 	DefaultConnectionGene(key=(-2400, 4), weight=-0.5440668040157346, enabled=True)
# 	DefaultConnectionGene(key=(-2399, 0), weight=0.8613737291304742, enabled=True)
# 	DefaultConnectionGene(key=(-2399, 1), weight=0.1907214141838327, enabled=True)
# 	DefaultConnectionGene(key=(-2399, 2), weight=0.23686413224259892, enabled=True)
# 	DefaultConnectionGene(key=(-2399, 3), weight=1.2331848559587293, enabled=True)
# 	DefaultConnectionGene(key=(-2399, 4), weight=0.7863788283019592, enabled=True)
# 	DefaultConnectionGene(key=(-2398, 0), weight=-1.6112276515396498, enabled=True)
# 	DefaultConnectionGene(key=(-2398, 1), weight=1.4935997876553442, enabled=True)
# 	DefaultConnectionGene(key=(-2398, 2), weight=-2.29027247138871, enabled=True)
# 	DefaultConnectionGene(key=(-2398, 3), weight=0.38151422582271094, enabled=True)
# 	DefaultConnectionGene(key=(-2398, 4), weight=0.41326820118173346, enabled=True)
# 	DefaultConnectionGene(key=(-2397, 0), weight=1.5293943113470452, enabled=True)
# 	DefaultConnectionGene(key=(-2397, 1), weight=-0.9082409817345547, enabled=True)
# 	DefaultConnectionGene(key=(-2397, 2), weight=-0.24633585831236188, enabled=True)
# 	DefaultConnectionGene(key=(-2397, 3), weight=0.6470955127014307, enabled=True)
# 	DefaultConnectionGene(key=(-2397, 4), weight=2.0927219668944317, enabled=True)
# 	DefaultConnectionGene(key=(-2396, 0), weight=-0.4306496381594322, enabled=True)
# 	DefaultConnectionGene(key=(-2396, 1), weight=0.6590443237519685, enabled=True)
# 	DefaultConnectionGene(key=(-2396, 2), weight=0.9632626547254287, enabled=True)
# 	DefaultConnectionGene(key=(-2396, 3), weight=0.6435006652786478, enabled=True)
# 	DefaultConnectionGene(key=(-2396, 4), weight=-1.3318854181482922, enabled=True)
# 	DefaultConnectionGene(key=(-2395, 0), weight=0.7793418655808098, enabled=True)
# 	DefaultConnectionGene(key=(-2395, 1), weight=0.24306324497836534, enabled=True)
# 	DefaultConnectionGene(key=(-2395, 2), weight=-0.25857729667012236, enabled=True)
# 	DefaultConnectionGene(key=(-2395, 3), weight=0.1820917488670851, enabled=True)
# 	DefaultConnectionGene(key=(-2395, 4), weight=0.9906157130834672, enabled=True)
# 	DefaultConnectionGene(key=(-2394, 0), weight=0.12724089993540522, enabled=True)
# 	DefaultConnectionGene(key=(-2394, 1), weight=0.6969920839311119, enabled=True)
# 	DefaultConnectionGene(key=(-2394, 2), weight=-0.5592864290888941, enabled=True)
# 	DefaultConnectionGene(key=(-2394, 3), weight=-0.1207212980844623, enabled=True)
# 	DefaultConnectionGene(key=(-2394, 4), weight=-0.6244819500210851, enabled=True)
# 	DefaultConnectionGene(key=(-2393, 0), weight=-0.13828443511878252, enabled=True)
# 	DefaultConnectionGene(key=(-2393, 1), weight=1.3735472477414399, enabled=True)
# 	DefaultConnectionGene(key=(-2393, 2), weight=-0.6843873590007944, enabled=True)
# 	DefaultConnectionGene(key=(-2393, 3), weight=-0.40150185167515257, enabled=True)
# 	DefaultConnectionGene(key=(-2393, 4), weight=0.7310841536367503, enabled=True)
# 	DefaultConnectionGene(key=(-2392, 0), weight=-0.6817082736468911, enabled=True)
# 	DefaultConnectionGene(key=(-2392, 1), weight=-1.26091138373119, enabled=True)
# 	DefaultConnectionGene(key=(-2392, 2), weight=0.5082241842925048, enabled=True)
# 	DefaultConnectionGene(key=(-2392, 3), weight=1.0628383231288505, enabled=True)
# 	DefaultConnectionGene(key=(-2392, 4), weight=0.6621810452003917, enabled=True)
# 	DefaultConnectionGene(key=(-2391, 0), weight=-0.1410344661849149, enabled=True)
# 	DefaultConnectionGene(key=(-2391, 1), weight=0.13054471654154992, enabled=True)
# 	DefaultConnectionGene(key=(-2391, 2), weight=-0.6270981925897294, enabled=True)
# 	DefaultConnectionGene(key=(-2391, 3), weight=-0.4475694926537552, enabled=True)
# 	DefaultConnectionGene(key=(-2391, 4), weight=-0.7513261694075983, enabled=True)
# 	DefaultConnectionGene(key=(-2390, 0), weight=0.01833996012499861, enabled=True)
# 	DefaultConnectionGene(key=(-2390, 1), weight=0.41150352224025527, enabled=True)
# 	DefaultConnectionGene(key=(-2390, 2), weight=-1.7164248379172877, enabled=True)
# 	DefaultConnectionGene(key=(-2390, 3), weight=1.3961676359598825, enabled=True)
# 	DefaultConnectionGene(key=(-2390, 4), weight=0.5978684569150317, enabled=True)
# 	DefaultConnectionGene(key=(-2389, 0), weight=-1.1679303059261494, enabled=True)
# 	DefaultConnectionGene(key=(-2389, 1), weight=1.5330055455840874, enabled=True)
# ...
# 	DefaultConnectionGene(key=(-41, 1), weight=-0.6295760939036217, enabled=True)
# 	DefaultConnectionGene(key=(-41, 2), weight=1.6889614960446246, enabled=True)
# 	DefaultConnectionGene(key=(-41, 3), weight=0.22803285735307485, enabled=True)
# 	DefaultConnectionGene(key=(-41, 4), weight=0.4135266233943542, enabled=True)
# 	DefaultConnectionGene(key=(-40, 0), weight=0.5053105290991285, enabled=True)
# 	DefaultConnectionGene(key=(-40, 1), weight=-1.062195674998641, enabled=True)
# 	DefaultConnectionGene(key=(-40, 2), weight=-0.8175278492174192, enabled=True)
# 	DefaultConnectionGene(key=(-40, 3), weight=0.9902137940690647, enabled=True)
# 	DefaultConnectionGene(key=(-40, 4), weight=0.27089324886971256, enabled=True)
# 	DefaultConnectionGene(key=(-39, 0), weight=-0.49971975474819086, enabled=True)
# 	DefaultConnectionGene(key=(-39, 1), weight=1.395419990997616, enabled=True)
# 	DefaultConnectionGene(key=(-39, 2), weight=0.017604094798922554, enabled=True)
# 	DefaultConnectionGene(key=(-39, 3), weight=0.14053539087834138, enabled=True)
# 	DefaultConnectionGene(key=(-39, 4), weight=0.9313420084141719, enabled=True)
# 	DefaultConnectionGene(key=(-38, 0), weight=1.8188135331991748, enabled=True)
# 	DefaultConnectionGene(key=(-38, 1), weight=-0.4472661130409237, enabled=True)
# 	DefaultConnectionGene(key=(-38, 2), weight=-0.357941823065269, enabled=True)
# 	DefaultConnectionGene(key=(-38, 3), weight=0.200982360990943, enabled=True)
# 	DefaultConnectionGene(key=(-38, 4), weight=-0.5739845834819097, enabled=True)
# 	DefaultConnectionGene(key=(-37, 0), weight=0.492237158280853, enabled=True)
# 	DefaultConnectionGene(key=(-37, 1), weight=-0.15180358311437042, enabled=True)
# 	DefaultConnectionGene(key=(-37, 2), weight=0.8029718795510059, enabled=False)
# 	DefaultConnectionGene(key=(-37, 3), weight=-1.464915587132802, enabled=True)
# 	DefaultConnectionGene(key=(-37, 4), weight=-1.120390603753037, enabled=True)
# 	DefaultConnectionGene(key=(-36, 0), weight=-0.22045119967588703, enabled=True)
# 	DefaultConnectionGene(key=(-36, 1), weight=-0.5326463266281231, enabled=True)
# 	DefaultConnectionGene(key=(-36, 2), weight=1.582059044631094, enabled=True)
# 	DefaultConnectionGene(key=(-36, 3), weight=2.5017971570377977, enabled=True)
# 	DefaultConnectionGene(key=(-36, 4), weight=0.9480113125198858, enabled=True)
# 	DefaultConnectionGene(key=(-35, 0), weight=-0.2905575300874473, enabled=True)
# 	DefaultConnectionGene(key=(-35, 1), weight=-0.2889663882167664, enabled=True)
# 	DefaultConnectionGene(key=(-35, 2), weight=-0.16832514793376985, enabled=True)
# 	DefaultConnectionGene(key=(-35, 3), weight=0.22641519930369025, enabled=False)
# 	DefaultConnectionGene(key=(-35, 4), weight=0.5891886002316008, enabled=True)
# 	DefaultConnectionGene(key=(-34, 0), weight=-0.9862970613762647, enabled=True)
# 	DefaultConnectionGene(key=(-34, 1), weight=-1.9848455131923377, enabled=True)
# 	DefaultConnectionGene(key=(-34, 2), weight=-0.21974860237523408, enabled=True)
# 	DefaultConnectionGene(key=(-34, 3), weight=0.7675680151141744, enabled=True)
# 	DefaultConnectionGene(key=(-34, 4), weight=0.4140342190229688, enabled=True)
# 	DefaultConnectionGene(key=(-33, 0), weight=0.44970022846012914, enabled=True)
# 	DefaultConnectionGene(key=(-33, 1), weight=-0.09029733681922698, enabled=True)
# 	DefaultConnectionGene(key=(-33, 2), weight=0.4951986045768747, enabled=True)
# 	DefaultConnectionGene(key=(-33, 3), weight=2.2797147882282616, enabled=True)
# 	DefaultConnectionGene(key=(-33, 4), weight=0.30820816626405706, enabled=True)
# 	DefaultConnectionGene(key=(-32, 0), weight=-0.4960501001689587, enabled=True)
# 	DefaultConnectionGene(key=(-32, 1), weight=-0.7916577479451323, enabled=True)
# 	DefaultConnectionGene(key=(-32, 2), weight=-0.37964433747010595, enabled=True)
# 	DefaultConnectionGene(key=(-32, 3), weight=0.05279871850659115, enabled=True)
# 	DefaultConnectionGene(key=(-32, 4), weight=0.7497186458606571, enabled=True)
# 	DefaultConnectionGene(key=(-31, 0), weight=-1.1239653659389537, enabled=True)
# 	DefaultConnectionGene(key=(-31, 1), weight=0.4293344599930597, enabled=True)
# 	DefaultConnectionGene(key=(-31, 2), weight=0.9074795933445213, enabled=True)
# 	DefaultConnectionGene(key=(-31, 3), weight=-0.3244576987125824, enabled=True)
# 	DefaultConnectionGene(key=(-31, 4), weight=2.307926740774211, enabled=True)
# 	DefaultConnectionGene(key=(-30, 0), weight=0.5834815191098175, enabled=True)
# 	DefaultConnectionGene(key=(-30, 1), weight=0.43714698102472543, enabled=True)
# 	DefaultConnectionGene(key=(-30, 2), weight=1.2066180405153535, enabled=True)
# 	DefaultConnectionGene(key=(-30, 3), weight=-0.28667056302563243, enabled=True)
# 	DefaultConnectionGene(key=(-30, 4), weight=0.12172192949696986, enabled=True)
# 	DefaultConnectionGene(key=(-29, 0), weight=1.404306653776096, enabled=True)
# 	DefaultConnectionGene(key=(-29, 1), weight=-0.796192687367772, enabled=True)
# 	DefaultConnectionGene(key=(-29, 2), weight=-0.4631407000036405, enabled=True)
# 	DefaultConnectionGene(key=(-29, 3), weight=-1.2432123402436466, enabled=True)
# 	DefaultConnectionGene(key=(-29, 4), weight=1.1426271169460076, enabled=True)
# 	DefaultConnectionGene(key=(-28, 0), weight=-1.567565093480191, enabled=True)
# 	DefaultConnectionGene(key=(-28, 1), weight=1.6643725461641512, enabled=True)
# 	DefaultConnectionGene(key=(-28, 2), weight=-0.7073983468422163, enabled=True)
# 	DefaultConnectionGene(key=(-28, 3), weight=1.08611310600512, enabled=True)
# 	DefaultConnectionGene(key=(-28, 4), weight=0.491744408307332, enabled=True)
# 	DefaultConnectionGene(key=(-27, 0), weight=0.20286102288885988, enabled=True)
# 	DefaultConnectionGene(key=(-27, 1), weight=0.2069467081575358, enabled=True)
# 	DefaultConnectionGene(key=(-27, 2), weight=1.2917803446017522, enabled=True)
# 	DefaultConnectionGene(key=(-27, 3), weight=-0.0011380391900824571, enabled=True)
# 	DefaultConnectionGene(key=(-27, 4), weight=-0.15136427168293484, enabled=True)
# 	DefaultConnectionGene(key=(-26, 0), weight=0.9091707896726303, enabled=True)
# 	DefaultConnectionGene(key=(-26, 1), weight=-0.8860268923748973, enabled=True)
# 	DefaultConnectionGene(key=(-26, 2), weight=0.5324635598578429, enabled=True)
# 	DefaultConnectionGene(key=(-26, 3), weight=-0.2622027490110483, enabled=True)
# 	DefaultConnectionGene(key=(-26, 4), weight=-0.2757790041761091, enabled=True)
# 	DefaultConnectionGene(key=(-25, 0), weight=-0.16301103029360037, enabled=True)
# 	DefaultConnectionGene(key=(-25, 1), weight=-0.032910013238822644, enabled=True)
# 	DefaultConnectionGene(key=(-25, 2), weight=-0.14914173539503178, enabled=True)
# 	DefaultConnectionGene(key=(-25, 3), weight=-0.16234853129023233, enabled=True)
# 	DefaultConnectionGene(key=(-25, 4), weight=0.4960931580904405, enabled=True)
# 	DefaultConnectionGene(key=(-24, 0), weight=0.5671812376206788, enabled=True)
# 	DefaultConnectionGene(key=(-24, 1), weight=-1.457890854339676, enabled=True)
# 	DefaultConnectionGene(key=(-24, 2), weight=0.7586873778384378, enabled=True)
# 	DefaultConnectionGene(key=(-24, 3), weight=0.604508168858117, enabled=True)
# 	DefaultConnectionGene(key=(-24, 4), weight=-1.1268605335863646, enabled=True)
# 	DefaultConnectionGene(key=(-23, 0), weight=-0.5306787526726297, enabled=True)
# 	DefaultConnectionGene(key=(-23, 1), weight=0.05059196833880955, enabled=True)
# 	DefaultConnectionGene(key=(-23, 2), weight=-0.2557647345460336, enabled=True)
# 	DefaultConnectionGene(key=(-23, 3), weight=-1.5855844221118327, enabled=True)
# 	DefaultConnectionGene(key=(-23, 4), weight=0.4170849020693085, enabled=True)
# 	DefaultConnectionGene(key=(-22, 0), weight=0.06612422587113276, enabled=True)
# 	DefaultConnectionGene(key=(-22, 1), weight=-1.4598929938054686, enabled=True)
# 	DefaultConnectionGene(key=(-22, 2), weight=1.188712319219075, enabled=True)
# 	DefaultConnectionGene(key=(-22, 3), weight=1.0292496873256267, enabled=True)
# 	DefaultConnectionGene(key=(-22, 4), weight=2.0989707206604007, enabled=True)
# 	DefaultConnectionGene(key=(-21, 0), weight=-1.4583321552559272, enabled=True)
# 	DefaultConnectionGene(key=(-21, 1), weight=-1.4491012190833452, enabled=True)
# 	DefaultConnectionGene(key=(-21, 2), weight=-0.6510901121025091, enabled=True)
# 	DefaultConnectionGene(key=(-21, 3), weight=0.3749843736931076, enabled=True)
# 	DefaultConnectionGene(key=(-21, 4), weight=-0.8705945443540948, enabled=True)
# 	DefaultConnectionGene(key=(-20, 0), weight=-1.0116780937998398, enabled=True)
# 	DefaultConnectionGene(key=(-20, 1), weight=-1.6356934708973607, enabled=True)
# 	DefaultConnectionGene(key=(-20, 2), weight=0.669529510689831, enabled=True)
# 	DefaultConnectionGene(key=(-20, 3), weight=-0.03543054418542296, enabled=True)
# 	DefaultConnectionGene(key=(-20, 4), weight=0.19235804652137162, enabled=True)
# 	DefaultConnectionGene(key=(-19, 0), weight=-1.9446046659153338, enabled=True)
# 	DefaultConnectionGene(key=(-19, 1), weight=0.7656237419951202, enabled=True)
# 	DefaultConnectionGene(key=(-19, 2), weight=-0.6148458818093666, enabled=True)
# 	DefaultConnectionGene(key=(-19, 3), weight=-0.9520925259848613, enabled=True)
# 	DefaultConnectionGene(key=(-19, 4), weight=0.720961654760389, enabled=True)
# 	DefaultConnectionGene(key=(-18, 0), weight=0.3912277901329999, enabled=True)
# 	DefaultConnectionGene(key=(-18, 1), weight=0.15338494058142654, enabled=True)
# 	DefaultConnectionGene(key=(-18, 2), weight=1.7295836701284233, enabled=True)
# 	DefaultConnectionGene(key=(-18, 3), weight=1.3840895498985772, enabled=True)
# 	DefaultConnectionGene(key=(-18, 4), weight=-1.3464168347395558, enabled=True)
# 	DefaultConnectionGene(key=(-17, 0), weight=-0.5168265108529099, enabled=True)
# 	DefaultConnectionGene(key=(-17, 1), weight=0.8570525742217467, enabled=True)
# 	DefaultConnectionGene(key=(-17, 2), weight=0.18416921622845184, enabled=True)
# 	DefaultConnectionGene(key=(-17, 3), weight=1.0630622087690065, enabled=True)
# 	DefaultConnectionGene(key=(-17, 4), weight=1.1560633560248272, enabled=True)
# 	DefaultConnectionGene(key=(-16, 0), weight=0.042405042518887215, enabled=True)
# 	DefaultConnectionGene(key=(-16, 1), weight=1.0442023245142467, enabled=True)
# 	DefaultConnectionGene(key=(-16, 2), weight=-0.43816716427671065, enabled=True)
# 	DefaultConnectionGene(key=(-16, 3), weight=0.12661923504645947, enabled=True)
# 	DefaultConnectionGene(key=(-16, 4), weight=-0.13369798995975402, enabled=True)
# 	DefaultConnectionGene(key=(-15, 0), weight=-0.6057360783833904, enabled=True)
# 	DefaultConnectionGene(key=(-15, 1), weight=-0.6855486835748087, enabled=True)
# 	DefaultConnectionGene(key=(-15, 2), weight=0.5004654224364194, enabled=True)
# 	DefaultConnectionGene(key=(-15, 3), weight=-1.8810586321804088, enabled=True)
# 	DefaultConnectionGene(key=(-15, 4), weight=-0.17503725920365634, enabled=True)
# 	DefaultConnectionGene(key=(-14, 0), weight=-0.16876761720968786, enabled=True)
# 	DefaultConnectionGene(key=(-14, 1), weight=-0.1432498474258403, enabled=True)
# 	DefaultConnectionGene(key=(-14, 2), weight=-0.49573634812194334, enabled=True)
# 	DefaultConnectionGene(key=(-14, 3), weight=-0.1298430296888248, enabled=True)
# 	DefaultConnectionGene(key=(-14, 4), weight=-0.5811865942549208, enabled=True)
# 	DefaultConnectionGene(key=(-13, 0), weight=-2.0570575803753686, enabled=True)
# 	DefaultConnectionGene(key=(-13, 1), weight=-0.483318899032259, enabled=True)
# 	DefaultConnectionGene(key=(-13, 2), weight=2.0405584007484685, enabled=True)
# 	DefaultConnectionGene(key=(-13, 3), weight=1.1615869689766167, enabled=True)
# 	DefaultConnectionGene(key=(-13, 4), weight=0.8908040523078018, enabled=True)
# 	DefaultConnectionGene(key=(-12, 0), weight=0.8626661925256742, enabled=True)
# 	DefaultConnectionGene(key=(-12, 1), weight=0.7948533684335987, enabled=True)
# 	DefaultConnectionGene(key=(-12, 2), weight=-0.2585243518756204, enabled=True)
# 	DefaultConnectionGene(key=(-12, 3), weight=0.4421820468105546, enabled=True)
# 	DefaultConnectionGene(key=(-12, 4), weight=-1.7482233371630616, enabled=True)
# 	DefaultConnectionGene(key=(-11, 0), weight=-1.7968216697395323, enabled=True)
# 	DefaultConnectionGene(key=(-11, 1), weight=-1.0261240757147294, enabled=True)
# 	DefaultConnectionGene(key=(-11, 2), weight=0.5947548617674532, enabled=True)
# 	DefaultConnectionGene(key=(-11, 3), weight=-0.02851370295335598, enabled=True)
# 	DefaultConnectionGene(key=(-11, 4), weight=2.0629451190649006, enabled=True)
# 	DefaultConnectionGene(key=(-10, 0), weight=-1.5452032320819162, enabled=True)
# 	DefaultConnectionGene(key=(-10, 1), weight=-0.8087797906978286, enabled=True)
# 	DefaultConnectionGene(key=(-10, 2), weight=-0.7115477540998961, enabled=True)
# 	DefaultConnectionGene(key=(-10, 3), weight=-0.8385950350290292, enabled=True)
# 	DefaultConnectionGene(key=(-10, 4), weight=1.4012947366150248, enabled=True)
# 	DefaultConnectionGene(key=(-9, 0), weight=-1.7700780034617134, enabled=True)
# 	DefaultConnectionGene(key=(-9, 1), weight=-0.5707568174253718, enabled=True)
# 	DefaultConnectionGene(key=(-9, 2), weight=-0.5782109831626454, enabled=True)
# 	DefaultConnectionGene(key=(-9, 3), weight=2.3868477499670164, enabled=True)
# 	DefaultConnectionGene(key=(-9, 4), weight=2.757155414006091, enabled=True)
# 	DefaultConnectionGene(key=(-8, 0), weight=-0.25433466578330427, enabled=True)
# 	DefaultConnectionGene(key=(-8, 1), weight=-0.32229605170824327, enabled=True)
# 	DefaultConnectionGene(key=(-8, 2), weight=-0.10806570055474018, enabled=True)
# 	DefaultConnectionGene(key=(-8, 3), weight=0.13400921582551328, enabled=True)
# 	DefaultConnectionGene(key=(-8, 4), weight=-0.8855913685466573, enabled=True)
# 	DefaultConnectionGene(key=(-7, 0), weight=-0.5197482180052316, enabled=True)
# 	DefaultConnectionGene(key=(-7, 1), weight=0.5010921572273102, enabled=True)
# 	DefaultConnectionGene(key=(-7, 2), weight=-1.151792712687058, enabled=True)
# 	DefaultConnectionGene(key=(-7, 3), weight=0.38069365142584694, enabled=True)
# 	DefaultConnectionGene(key=(-7, 4), weight=-1.1691763934559494, enabled=True)
# 	DefaultConnectionGene(key=(-6, 0), weight=2.3479791821458442, enabled=True)
# 	DefaultConnectionGene(key=(-6, 1), weight=0.2402036036838538, enabled=True)
# 	DefaultConnectionGene(key=(-6, 2), weight=1.4817584601279976, enabled=True)
# 	DefaultConnectionGene(key=(-6, 3), weight=0.134441458314078, enabled=True)
# 	DefaultConnectionGene(key=(-6, 4), weight=-1.4502585693217638, enabled=True)
# 	DefaultConnectionGene(key=(-5, 0), weight=0.40288638343222033, enabled=True)
# 	DefaultConnectionGene(key=(-5, 1), weight=-1.0216782721521729, enabled=True)
# 	DefaultConnectionGene(key=(-5, 2), weight=-0.5248939001016736, enabled=True)
# 	DefaultConnectionGene(key=(-5, 3), weight=-0.09348424128065963, enabled=True)
# 	DefaultConnectionGene(key=(-5, 4), weight=-1.8766765529263583, enabled=True)
# 	DefaultConnectionGene(key=(-4, 0), weight=0.28343952361000996, enabled=True)
# 	DefaultConnectionGene(key=(-4, 1), weight=0.07807233576655837, enabled=True)
# 	DefaultConnectionGene(key=(-4, 2), weight=1.5084723237935145, enabled=True)
# 	DefaultConnectionGene(key=(-4, 3), weight=-0.9685892726368779, enabled=True)
# 	DefaultConnectionGene(key=(-4, 4), weight=1.4902449334396004, enabled=True)
# 	DefaultConnectionGene(key=(-3, 0), weight=-0.09133818720601347, enabled=True)
# 	DefaultConnectionGene(key=(-3, 1), weight=1.4571927063515044, enabled=True)
# 	DefaultConnectionGene(key=(-3, 2), weight=0.19591612459543825, enabled=True)
# 	DefaultConnectionGene(key=(-3, 3), weight=1.0787792536580878, enabled=True)
# 	DefaultConnectionGene(key=(-3, 4), weight=0.9290717790035634, enabled=True)
# 	DefaultConnectionGene(key=(-2, 0), weight=1.438764818232529, enabled=True)
# 	DefaultConnectionGene(key=(-2, 1), weight=-0.851031732958117, enabled=True)
# 	DefaultConnectionGene(key=(-2, 2), weight=0.4437283490128573, enabled=True)
# 	DefaultConnectionGene(key=(-2, 3), weight=0.45238949872120293, enabled=True)
# 	DefaultConnectionGene(key=(-2, 4), weight=1.0359623439719414, enabled=True)
# 	DefaultConnectionGene(key=(-1, 0), weight=0.900566218048041, enabled=False)
# 	DefaultConnectionGene(key=(-1, 1), weight=0.13367848948599848, enabled=True)
# 	DefaultConnectionGene(key=(-1, 2), weight=-0.49086488701506753, enabled=True)
# 	DefaultConnectionGene(key=(-1, 3), weight=-1.4123103484896067, enabled=True)
# 	DefaultConnectionGene(key=(-1, 4), weight=0.7103049718097387, enabled=True)

# %%
agent_1 = rand_agent()
agent_2 = rand_enemy_agent()


h = 20
w = 20
test_game = cgol(agent_1, agent_2,board_h = h,board_w = w, max_rounds = 50, map = np.random.binomial(1,0.1,(h,w)))

win_record, game_hist, action_hist = test_game.run_game(1, training=False)

# play the last episode/game
anim = anim_builder(game_hist[-1], action_hist[-1])

# %%
#plot gif style
anim
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgcb7633763a9a4226b15ee44e0dc80eea">
#   <div class="anim-controls">
#     <input id="_anim_slidercb7633763a9a4226b15ee44e0dc80eea" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animcb7633763a9a4226b15ee44e0dc80eea.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="animcb7633763a9a4226b15ee44e0dc80eea.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="animcb7633763a9a4226b15ee44e0dc80eea.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="animcb7633763a9a4226b15ee44e0dc80eea.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="animcb7633763a9a4226b15ee44e0dc80eea.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="animcb7633763a9a4226b15ee44e0dc80eea.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="animcb7633763a9a4226b15ee44e0dc80eea.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="animcb7633763a9a4226b15ee44e0dc80eea.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="animcb7633763a9a4226b15ee44e0dc80eea.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="animcb7633763a9a4226b15ee44e0dc80eea.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_selectcb7633763a9a4226b15ee44e0dc80eea"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_cb7633763a9a4226b15ee44e0dc80eea"
#              >
#       <label for="_anim_radio1_cb7633763a9a4226b15ee44e0dc80eea">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_cb7633763a9a4226b15ee44e0dc80eea"
#              checked>
#       <label for="_anim_radio2_cb7633763a9a4226b15ee44e0dc80eea">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_cb7633763a9a4226b15ee44e0dc80eea"
#              >
#       <label for="_anim_radio3_cb7633763a9a4226b15ee44e0dc80eea">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgcb7633763a9a4226b15ee44e0dc80eea";
#     var slider_id = "_anim_slidercb7633763a9a4226b15ee44e0dc80eea";
#     var loop_select_id = "_anim_loop_selectcb7633763a9a4226b15ee44e0dc80eea";
#     var frames = new Array(19);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjcuMSwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/bCgiHAAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAAA5P0lEQ

# %%
#save the gif for an individual game
anim.save('test_anim.gif', writer='pillow', fps=5)
